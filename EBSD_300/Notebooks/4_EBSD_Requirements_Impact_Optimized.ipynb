# %% [markdown]
# # Generative AI Enabled Simcenter Studio Notebook
# ## System Impact Due to Requirement Changes
#
# This notebook takes the requirement located on model diagram "[PAB] Node Structure with Deployed Behaviors and requirements" and displays them in a table.
# These requirements were placed on the diagram based on them being identified as being impacted.
# The requirements are then used to determine the impact that they will have on the EBSD components by leveraging the knowledge captured in the notebook. A prompt is used to define the analysis and report format displayed.

# %%
from se_agent.core.agent import AgentCore

#agent = AgentCore(debug=True)
agent = AgentCore()
agent.create_package("SE_Solutions")
agent.use_package("SE_Solutions")
# Out:
# /usr/local/lib/python3.12/dist-packages/langgraph/checkpoint/serde/encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer
# 🧩 Registered tool: build_capella_model_embeddings – BUILD AND REGISTER EMBEDDINGS FOR A CAPELLA MODEL. (modes=('DEFAULT',))
# 🧩 Registered tool: create_artifact – Create a new artifact with the given name, type, and content in the target package. (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: create_capella_model_artifact – CREATE A SINGLE CAPELLA_MODEL ARTIFACT FROM PATH AND RESOURCES. (modes=('DEFAULT',))
# ⚠️ Tool 'create_file_reference' did not declare APPLICABLE_MODES; defaulting to ('DEFAULT',).
# ...

# %% [markdown]
# ### Step 1: Run `create_capella_model_artifact`
# Package: `SE_Solutions`
# Input: `{'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird', 'resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}, 'name': 'EBSD_300'}`

# %%
#agent.act("/t create_capella_model_artifact','path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird','name': 'EBSD_300','resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}}")
_ = agent.run('create_capella_model_artifact', package_name='SE_Solutions', input_data={'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird', 'resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}, 'name': 'EBSD_300'}, **{})
# Out:
# input data: {'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird', 'resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}, 'name': 'EBSD_300'}
# ✅ Artifact created: name='_workspace_store' id='49c6d49f' type='workspace' in package 'SE_Solutions'
# resolved input: {'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird', 'resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}, 'name': 'EBSD_300'}
# JIT Input: {'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird', 'resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}, 'name': 'EBSD_300'}
# ✅ Artifact created: name='EBSD_300' id='fd7127ed' type='capella_model' in package 'SE_Solutions'

# %% [markdown]
# ### Step 2: Run `load_prompt_path`
# Package: `SE_Solutions`
# Input: `{'prompt_dir_path': '/home/simcenter/studio/EBSD_300/EBSD_300/Notebooks/prompt_library', 'name': 'prompt_dir_path'}`

# %%
#res = agent.act('/t load_prompt_path prompt_dir_path :  "/home/simcenter/studio/EBSD_300/EBSD_300/Notebooks/prompt_library" , Name:  "prompt_dir_path" ')
##from pprint import pprint; pprint(res)
_ = agent.run('load_prompt_path', package_name='SE_Solutions', input_data={'prompt_dir_path': '/home/simcenter/studio/EBSD_300/EBSD_300/Notebooks/prompt_library', 'name': 'prompt_dir_path'}, **{})
# Out:
# input data: {'prompt_dir_path': '/home/simcenter/studio/EBSD_300/EBSD_300/Notebooks/prompt_library', 'name': 'prompt_dir_path'}
# resolved input: {'prompt_dir_path': '/home/simcenter/studio/EBSD_300/EBSD_300/Notebooks/prompt_library', 'name': 'prompt_dir_path'}
# JIT Input: {'prompt_dir_path': '/home/simcenter/studio/EBSD_300/EBSD_300/Notebooks/prompt_library', 'name': 'prompt_dir_path'}
# ✅ Artifact created: name='prompt_dir_path' id='749c3c6b' type='prompt_path' in package 'SE_Solutions'

# %% [markdown]
# ### Step 3: Run `create_artifact`
# Package: `SE_Solutions`
# Input: `{'name': 'Requirement', 'type': 'prompt', 'content': '[PAB] Node Structure with Deployed Behaviors and requirements'}`

# %%
#res = agent.act('/t create_artifact of type prompt it name should be Requirement and it content should be  "[PAB] Node Structure with Deployed Behaviors and requirements"')
##from pprint import pprint; pprint(res)
_ = agent.run('create_artifact', package_name='SE_Solutions', input_data={'name': 'Requirement', 'type': 'prompt', 'content': '[PAB] Node Structure with Deployed Behaviors and requirements'}, **{})
# Out:
# input data: {'name': 'Requirement', 'type': 'prompt', 'content': '[PAB] Node Structure with Deployed Behaviors and requirements'}
# resolved input: {'name': 'Requirement', 'type': 'prompt', 'content': '[PAB] Node Structure with Deployed Behaviors and requirements'}
# JIT Input: {'name': 'Requirement', 'type': 'prompt', 'content': '[PAB] Node Structure with Deployed Behaviors and requirements'}
# ✅ Artifact created: name='Requirement' id='ec2b376c' type='prompt' in package 'SE_Solutions'
# [remember] create_artifact: declared remember for ['artifact_id'] but no artifact_ids returned.

# %% [markdown]
# ### Step 4: Run `build_capella_model_embeddings`
# Package: `SE_Solutions`
# Input: `{'capella_model': {'type': 'capella_model', 'name': 'EBSD_300'}}`

# %%
#res = agent.act('/t build_capella_model_embeddings capella_model: {"type": "capella_model", "name": "EBSD_300" }')
##from pprint import pprint; pprint(res)
_ = agent.run('build_capella_model_embeddings', package_name='SE_Solutions', input_data={'capella_model': {'type': 'capella_model', 'name': 'EBSD_300'}}, **{})
# Out:
# input data: {'capella_model': {'type': 'capella_model', 'name': 'EBSD_300'}}
# resolved input: {'capella_model': {'type': 'capella_model', 'name': 'EBSD_300'}}
# JIT Input: {'capella_model': {'artifact_id': 'fd7127ed-b2b1-49b1-b64d-cece28b428e2'}}
# ✅ EmbeddingManager initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: text-embedding-3-small
# Loading embeddings
# embeddings loaded.
# ✅ Artifact created: name='EBSD_300_emb' id='154ec444' type='embeddings' in package 'SE_Solutions'

# %% [markdown]
# ### Step 5: Run `query_capella_embeddings`
# Package: `SE_Solutions`
# Input: `{'embeddings': {'type': 'embeddings', 'name': 'EBSD_300_emb'}, 'prompt': {'type': 'prompt', 'name': 'Requirement'}, 'top_n': 1}`

# %%
#
#res = agent.act('/t query_capella_embeddings EBSD_300_emb with prompt artifact name ="Requirement" return to 1 ')
##from pprint import pprint; pprint(res)
_ = agent.run('query_capella_embeddings', package_name='SE_Solutions', input_data={'embeddings': {'type': 'embeddings', 'name': 'EBSD_300_emb'}, 'prompt': {'type': 'prompt', 'name': 'Requirement'}, 'top_n': 1}, **{})
# Out:
# input data: {'embeddings': {'type': 'embeddings', 'name': 'EBSD_300_emb'}, 'prompt': {'type': 'prompt', 'name': 'Requirement'}, 'top_n': 1}
# resolved input: {'embeddings': {'type': 'embeddings', 'name': 'EBSD_300_emb'}, 'prompt': {'type': 'prompt', 'name': 'Requirement'}, 'top_n': 1}
# JIT Input: {'embeddings': {'artifact_id': '154ec444-4912-409d-89ec-1c9c1e04a116'}, 'prompt': {'artifact_id': 'ec2b376c-05a2-4195-b979-c255243c546d'}, 'top_n': 1}
# ✅ EmbeddingManager initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: text-embedding-3-small
# Loading embeddings
# embeddings loaded.
# ✅ Embedding created in 1.09s [query=[PAB] Node Structure with Deployed Behaviors and requirements]
#
# This is a list of ranked Objects Based on Query:
# Index: 0, Name: [PAB] Node Structure with Deployed Behaviors and requirements, Similarity: 0.84, Type: DRepresentationDescriptor, Phase: Physical Architecture PA, Source: , Target:
# ...

# %% [markdown]
# ### Step 6: Run `table_column_to_list`
# Package: `SE_Solutions`
# Input: `{'table': {'type': 'table', 'name': 'EBSD_300_emb_query_results'}, 'column': 'uuid', 'name': 'EBSD_300_uuids'}`

# %%
#res = agent.act("/t table column to list  column: uuid , name the list EBSD_300_uuids")
##from pprint import pprint; pprint(res)
_ = agent.run('table_column_to_list', package_name='SE_Solutions', input_data={'table': {'type': 'table', 'name': 'EBSD_300_emb_query_results'}, 'column': 'uuid', 'name': 'EBSD_300_uuids'}, **{})
# Out:
# input data: {'table': {'type': 'table', 'name': 'EBSD_300_emb_query_results'}, 'column': 'uuid', 'name': 'EBSD_300_uuids'}
# resolved input: {'table': {'type': 'table', 'name': 'EBSD_300_emb_query_results'}, 'column': 'uuid', 'name': 'EBSD_300_uuids'}
# JIT Input: {'table': {'artifact_id': '2bf006c1-8b3c-40f2-9dd9-b310be008051'}, 'column': 'uuid', 'name': 'EBSD_300_uuids'}
# ✅ Artifact created: name='EBSD_300_uuids' id='27df0c73' type='list' in package 'SE_Solutions'

# %% [markdown]
# ### Step 7: Run `generate_arcadia_fabric`
# Package: `SE_Solutions`
# Input: `{'capella_model': {'type': 'capella_model', 'name': 'EBSD_300'}, 'targets_list': {'type': 'list', 'name': 'EBSD_300_uuids'}}`

# %%
#res = agent.act('/t generate_arcadia_fabric capella_model: {"artifact_type": "capella_model", "name": "EBSD_300" }, targets_list: {"type": "list", "name": "EBSD_300_uuids"}')
##from pprint import pprint; pprint(res)
_ = agent.run('generate_arcadia_fabric', package_name='SE_Solutions', input_data={'capella_model': {'type': 'capella_model', 'name': 'EBSD_300'}, 'targets_list': {'type': 'list', 'name': 'EBSD_300_uuids'}}, **{})
# Out:
# input data: {'capella_model': {'type': 'capella_model', 'name': 'EBSD_300'}, 'targets_list': {'type': 'list', 'name': 'EBSD_300_uuids'}}
# resolved input: {'capella_model': {'type': 'capella_model', 'name': 'EBSD_300'}, 'targets_list': {'type': 'list', 'name': 'EBSD_300_uuids'}}
# JIT Input: {'capella_model': {'artifact_id': 'fd7127ed-b2b1-49b1-b64d-cece28b428e2'}, 'targets_list': {'artifact_id': '27df0c73-3f1b-40ec-be04-d7516822105d'}}
# /usr/local/lib/python3.12/dist-packages/jinja2/environment.py:490: FutureWarning: ComponentPortAllocation cannot have a '.name', please update your code to check if the field exists or if the object subclasses modellingcore.AbstractNamedElement
#   return getattr(obj, attribute)
# /usr/local/lib/python3.12/dist-packages/jinja2/environment.py:490: FutureWarning: CapellaOutgoingRelation cannot have a '.name', please update your code to check if the field exists or if the object subclasses modellingcore.AbstractNamedElement
# ...

# %% [markdown]
# ### Step 8: Run `load_prompt_def_artifact`
# Package: `SE_Solutions`
# Input: `{'prompt_dir_ref': {'type': 'prompt_path', 'name': 'prompt_dir_path'}, 'prompt_title': 'Capella_Requirement'}`

# %%
#res = agent.act('/t load_prompt_def_artifact prompt_title: "Capella_Requirement", using prompt_dir_ref: prompt_dir_path' )
##from pprint import pprint; pprint(res)
##Start interactive chat with file attach + artifact capture
## Call chat as a tool
##agent.run("interactive_chat", input_data={
##    "context": "You are a systems engineering assistant."
##}, agent=agent)
_ = agent.run('load_prompt_def_artifact', package_name='SE_Solutions', input_data={'prompt_dir_ref': {'type': 'prompt_path', 'name': 'prompt_dir_path'}, 'prompt_title': 'Capella_Requirement'}, **{})
# Out:
# input data: {'prompt_dir_ref': {'type': 'prompt_path', 'name': 'prompt_dir_path'}, 'prompt_title': 'Capella_Requirement'}
# resolved input: {'prompt_dir_ref': {'type': 'prompt_path', 'name': 'prompt_dir_path'}, 'prompt_title': 'Capella_Requirement'}
# JIT Input: {'prompt_dir_ref': {'artifact_id': '749c3c6b-ede6-4213-8de2-4ea1f85fedd8'}, 'prompt_title': 'Capella_Requirement'}
# ✅ Artifact created: name='Capella_Requirement' id='cce031c6' type='prompt_def' in package 'SE_Solutions'

# %% [markdown]
# ### Step 9: Run `render_prompt_artifact`
# Package: `SE_Solutions`
# Input: `{'prompt_def': {'type': 'prompt_def', 'name': 'Capella_Requirement'}, 'output_name': 'Capella_Requirment_Rend'}`

# %%
#res = agent.act('/t render_prompt_artifact {"prompt_def": {"type":"prompt_def", "name":"Capella_Requirement"}, output_name: "Capella_Requirment_Rend" }')
##from pprint import pprint; pprint(res)
_ = agent.run('render_prompt_artifact', package_name='SE_Solutions', input_data={'prompt_def': {'type': 'prompt_def', 'name': 'Capella_Requirement'}, 'output_name': 'Capella_Requirment_Rend'}, **{})
# Out:
# input data: {'prompt_def': {'type': 'prompt_def', 'name': 'Capella_Requirement'}, 'output_name': 'Capella_Requirment_Rend'}
# resolved input: {'prompt_def': {'type': 'prompt_def', 'name': 'Capella_Requirement'}, 'output_name': 'Capella_Requirment_Rend'}
# JIT Input: {'prompt_def': {'artifact_id': 'cce031c6-984e-4075-bc48-f0e7aa333cac'}, 'output_name': 'Capella_Requirment_Rend'}
# ✅ Artifact created: name='Capella_Requirment_Rend' id='ea5c99c3' type='prompt' in package 'SE_Solutions'

# %% [markdown]
# ### Step 10: Run `reason_on_arcadia_fabric_or_files`
# Package: `SE_Solutions`
# Input: `{'arcadia_fabric_name': 'arcadia_fabric_fab', 'prompt_name': 'Capella_Requirment_Rend'}`

# %%
#res = agent.act('/t reason_on_arcadia_fabric_or_files using arcadia_fabric_name="arcadia_fabric_fab" , and prompt_name: Capella_Requirment_Rend' )
##res = agent.act('/t reason_and_publish_on_arcadia_fabric_files output_dir=./reports arcadia_fabric_name=arcadia_fabric_fab  prompt= Capella_Requirment_Rend')
_ = agent.run('reason_on_arcadia_fabric_or_files', package_name='SE_Solutions', input_data={'arcadia_fabric_name': 'arcadia_fabric_fab', 'prompt_name': 'Capella_Requirment_Rend'}, **{})
# Out:
# input data: {'arcadia_fabric_name': 'arcadia_fabric_fab', 'prompt_name': 'Capella_Requirment_Rend'}
# resolved input: {'arcadia_fabric_name': 'arcadia_fabric_fab', 'prompt_name': 'Capella_Requirment_Rend'}
# JIT Input: {'arcadia_fabric_name': 'arcadia_fabric_fab', 'prompt_name': 'Capella_Requirment_Rend'}
# ...
# ✅ ChatGPTAnalyzer initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: gpt-5.1
# 🏢 Provider: Open AI
# **Your prompt:** Please analyze the yaml file and display all Requirements for the diagram:
# 1. Format the requirement in a table.
# 2. Include its prefix, name, long_name, text, its relations and relation target. Format the response in .html format.
# <table border="1" cellpadding="4" cellspacing="0">
# <thead>
# <tr>
# <th>Prefix</th>
# <th>Name</th>
# <th>Long Name</th>
# <th>Text (HTML)</th>
# <th>Relations (UUID)</th>
# <th>Relation Type</th>
# <th>Relation Target Name</th>
# <th>Relation Target UUID</th>
# </tr>
# </thead>
# ...

# %% [markdown]
# ### Step 11: Run `load_prompt_def_artifact`
# Package: `SE_Solutions`
# Input: `{'prompt_dir_ref': {'type': 'prompt_path', 'name': 'prompt_dir_path'}, 'prompt_title': 'Identify_and_Justify_Physical_Component_Change'}`

# %%
#res = agent.act('/t load_prompt_def_artifact prompt_title: "Identify_and_Justify_Physical_Component_Change" prompt_dir_ref: prompt_dir_path' )
##from pprint import pprint; pprint(res)
_ = agent.run('load_prompt_def_artifact', package_name='SE_Solutions', input_data={'prompt_dir_ref': {'type': 'prompt_path', 'name': 'prompt_dir_path'}, 'prompt_title': 'Identify_and_Justify_Physical_Component_Change'}, **{})
# Out:
# input data: {'prompt_dir_ref': {'type': 'prompt_path', 'name': 'prompt_dir_path'}, 'prompt_title': 'Identify_and_Justify_Physical_Component_Change'}
# resolved input: {'prompt_dir_ref': {'type': 'prompt_path', 'name': 'prompt_dir_path'}, 'prompt_title': 'Identify_and_Justify_Physical_Component_Change'}
# JIT Input: {'prompt_dir_ref': {'artifact_id': '749c3c6b-ede6-4213-8de2-4ea1f85fedd8'}, 'prompt_title': 'Identify_and_Justify_Physical_Component_Change'}
# ✅ Artifact created: name='Identify_and_Justify_Physical_Component_Change' id='1f0a282c' type='prompt_def' in package 'SE_Solutions'

# %% [markdown]
# ### Step 12: Run `render_prompt_artifact`
# Package: `SE_Solutions`
# Input: `{'prompt_def': {'type': 'prompt_def', 'name': 'Identify_and_Justify_Physical_Component_Change'}, 'output_name': 'IJPC_Rend'}`

# %%
#res = agent.act('/t render_prompt_artifact {"prompt_def": {"type":"prompt_def", "name":"Identify_and_Justify_Physical_Component_Change"}, output_name: "IJPC_Rend" }')
##from pprint import pprint; pprint(res)
_ = agent.run('render_prompt_artifact', package_name='SE_Solutions', input_data={'prompt_def': {'type': 'prompt_def', 'name': 'Identify_and_Justify_Physical_Component_Change'}, 'output_name': 'IJPC_Rend'}, **{})
# Out:
# input data: {'prompt_def': {'type': 'prompt_def', 'name': 'Identify_and_Justify_Physical_Component_Change'}, 'output_name': 'IJPC_Rend'}
# resolved input: {'prompt_def': {'type': 'prompt_def', 'name': 'Identify_and_Justify_Physical_Component_Change'}, 'output_name': 'IJPC_Rend'}
# JIT Input: {'prompt_def': {'artifact_id': '1f0a282c-6a97-4c14-9140-ce551539bed7'}, 'output_name': 'IJPC_Rend'}
# ✅ Artifact created: name='IJPC_Rend' id='9eb37b40' type='prompt' in package 'SE_Solutions'

# %% [markdown]
# ### Step 13: Run `reason_on_arcadia_fabric_or_files`
# Package: `SE_Solutions`
# Input: `{'arcadia_fabric_name': 'arcadia_fabric_fab', 'prompt_name': 'IJPC_Rend'}`

# %%
res = agent.act('/t reason_on_arcadia_fabric_or_files using arcadia_fabric_name="arcadia_fabric_fab", and prompt_name: IJPC_Rend' )
##from pprint import pprint; pprint(res)
#_ = agent.run('reason_on_arcadia_fabric_or_files', package_name='SE_Solutions', input_data={'arcadia_fabric_name': 'arcadia_fabric_fab', 'prompt_name': 'IJPC_Rend'}, **{})
# Out:
# ✅ Planned tool actions now executing:{"actions":[{"tool":"reason_on_arcadia_fabric_or_files","input":{"arcadia_fabric_name":"arcadia_fabric_fab","prompt_name":"IJPC_Rend"}}]}
# **Your prompt:** Context:
# You are acting as a systems engineering Knowledge Partner working against a loaded Arcadia fabric file. The fabric contains requirements, requirement relations, model elements, and architecture context including PhysicalComponent Node components, functions, ports, interfaces, exchanges, and descriptions.
#
# Your task is to identify requirements related to PhysicalComponent Node components and generate a detailed, model-grounded rationale explaining why those nodes would be impacted by a requirement change.
#
# Use only the loaded fabric. Do not generate code.
#
# Instructions:
#
# Step 1 — Find relevant requirements
# ...

# %% [markdown]
# ### Step 14: Run `write_csv`
# Package: `SE_Solutions`
# Input: `{'filename': 'EBSD_Component_Impacts.csv', 'from_last_message': True}`

# %%
res = agent.act('/t write_csv filename="EBSD_Component_Impacts.csv" from_last_message=true')
##from pprint import pprint; pprint(res)
#_ = agent.run('write_csv', package_name='SE_Solutions', input_data={'filename': 'EBSD_Component_Impacts.csv', 'from_last_message': True}, **{})
