# %% [markdown]
# # Generative AI Enabled Simcenter Studio Notebook
# ## Needs extraction from Model
#
# Requirements are extracted from the system model diagram "Logical Architecture Diagram  [LAB] Requirements"" and captured in a file named "EBSD_Requirements.csv".
# The extraction and formatting of report is done by predefined prompt.

# %%
from se_agent.core.agent import AgentCore

#agent = AgentCore(debug=True)
agent = AgentCore()
agent.create_package("SE_Solutions")
agent.use_package("SE_Solutions")


#res = agent.run('load_prompt_path', input_data={'prompt_dir_path': '/home/simcenter/studio/knowledge_partner/prompt_library/' })
#from pprint import pprint; pprint(res)
agent.run('create_capella_model_artifact', input_data=
          {'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird',
           'name': 'EBSD_300',
           'resources': {"EBSD": "/home/simcenter/studio/EBSD_300/EBSD_300"}})
# Out:
# 🧩 Registered tool: build_capella_model_embeddings – BUILD AND REGISTER EMBEDDINGS FOR A CAPELLA MODEL. (modes=('DEFAULT',))
# 🧩 Registered tool: create_artifact – Create a new artifact with the given name, type, and content in the target package. (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: create_capella_model_artifact – CREATE A SINGLE CAPELLA_MODEL ARTIFACT FROM PATH AND RESOURCES. (modes=('DEFAULT',))
# ⚠️ Tool 'create_file_reference' did not declare APPLICABLE_MODES; defaulting to ('DEFAULT',).
# 🧩 Registered tool: create_file_reference – Create a 'file_reference' artifact for a local file (path + metadata only). (modes=('DEFAULT',))
# 🧩 Registered tool: create_folder_path – CREATE A FOLDER_PATH ARTIFACT FROM A DIRECTORY PATH (OPTIONALLY CREATE THE DIRECTORY). (modes=('DEFAULT',))
# 🧩 Registered tool: create_scaffold_artifact_for_tool – Create a blank spec artifact for a tool's artifact_ref input by inspecting the tool's IO_SCHEMA. (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: create_sysmlv2_snapshot_artifact – CREATE A SINGLE SYSML V2 SNAPSHOT ARTIFACT FROM REPO/PROJECT/COMMIT IDS. (modes=('DEFAULT',))
# 🧩 Registered tool: execute_diagram_retrieve – QUERY CAPELLA EMBEDDINGS, FIND SVG SNAPSHOT DIAGRAMS BY NAME, CREATE DIAGRAM ARTIFACTS, DISPLAY INLINE. (modes=('DEFAULT',))
# ⚠️ Tool 'execute_display_context_diagram' did not declare APPLICABLE_MODES; defaulting to ('DEFAULT',).
# 🧩 Registered tool: execute_display_context_diagram –  (modes=('DEFAULT',))
# 🧩 Registered tool: execute_fabric_publish – Publish a Markdown report generated directly from an arcadia_fabric YAML (and optional file_reference content) without vector-store retrieval. Mirrors execute_rag_publish publishing behaviors. (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: execute_prompt_for_session – Start a Creative/Freeform Session from an optional prompt artifact; optionally attach other artifacts (incl. file_artifact/file_reference) into Session Workspace Memory. (modes=('DEFAULT',))
# ⚠️ Tool 'execute_publish_context_diagram' did not declare APPLICABLE_MODES; defaulting to ('DEFAULT',).
# 🧩 Registered tool: execute_publish_context_diagram – Publish markdown and optional HTML/meta.json for Capella context diagrams for a list of UUIDs. Generates SVG files using obj.context_diagram.render('svgdiagram', mode=...). (modes=('DEFAULT',))
# 🧩 Registered tool: execute_publish_diagram_retrieve – QUERY EMBEDDINGS → FIND SVG SNAPSHOTS → COPY+PUBLISH MD/HTML/META (CSID bundle). (modes=('DEFAULT',))
# 🧩 Registered tool: execute_rag_analysis – Summarize/analyze one or more file_artifact documents using RAG over their OpenAI vector stores. Provide either 'summary_prompt' (string) or 'prompt' (prompt artifact ref). (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: execute_rag_publish – Publish a RAG-generated Markdown report to disk (optionally HTML + meta.json), using file_artifact sources indexed in vector stores. Captures provenance for CSID. (modes=('DEFAULT', 'SESSION'))
# ⚠️ Tool 'extract_word_tables_to_csv' did not declare APPLICABLE_MODES; defaulting to ('DEFAULT',).
# 🧩 Registered tool: extract_word_tables_to_csv – Extract tables from a Word .docx to multiple CSVs plus manifest.yaml; registers file_references. (modes=('DEFAULT',))
# 🧩 Registered tool: name_artifact – ASSIGN A NAME TO AN EXISTING ARTIFACT (LOOKUP BY ID OR LATEST OF TYPE). (modes=('DEFAULT',))
# 🧩 Registered tool: generate_arcadia_fabric – GENERATE ARCADIA YAML FABRIC FROM A CAPELLA MODEL AND A LIST OF UUIDS. (modes=('DEFAULT',))
# 🧩 Registered tool: generate_sysmlv2_fabric – GENERATES A SYSML V2 QUERY-BASED FABRIC, SAVES AS JSON, AND UPLOADS AS FILE ARTIFACT. (modes=('DEFAULT',))
# 🧩 Registered tool: interactive_chat – LAUNCHES AN INTERACTIVE CHAT SESSION; USES LLM_CHAT INTERNALLY. (modes=('DEFAULT',))
# 🧩 Registered tool: list_artifacts – List artifacts in the active (or specified) package with a Markdown summary. Optional filters: type, max_rows. (modes=('DEFAULT',))
# 🧩 Registered tool: list_workspace – DISPLAYS THE CURRENT WORKSPACE CONTENTS: ARTIFACTS AND MEMORY ENTRIES (with Markdown summary). (modes=('DEFAULT',))
# 🧩 Registered tool: llm_chat – CONDUCTS A TOOL-AWARE CHAT WITH THE LLM AND STORES CONVERSATION TURNS. (modes=('DEFAULT',))
# 🧩 Registered tool: load_artifact_into_workspace_memory – Load an artifact into workspace ⚙️ memory by ref/name or latest type; optional rename; returns one-shot injection. (modes=('DEFAULT',))
# 🧩 Registered tool: load_from_workspace_memory_to_artifact – LOAD A WORKSPACE MEMORY ENTRY AS A TYPED ARTIFACT (FOR TOOL USE). (modes=('DEFAULT',))
# 🧩 Registered tool: load_prompt_def_artifact – Load a prompt JSON from a directory (or prompt_path reference) and create an artifact of type 'prompt'. (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: load_prompt_path – LOADS A DIRECTORY OF NOTEBOOK-DEFINED PROMPTS AND SAVES A POINTER ARTIFACT FOR OTHER TOOLS TO USE. (modes=('DEFAULT',))
# 🧩 Registered tool: notebook_export – EXPORT AGENT HISTORY AS A REPLAY NOTEBOOK AND/OR EXPORT HTML SNAPSHOTS (WITH OPTIONAL CHAT TRANSCRIPT INJECTION). (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: query_capella_embeddings – QUERY A PRE-BUILT CAPELLA EMBEDDINGS ARTIFACT USING A PROMPT. (modes=('DEFAULT',))
# 🧩 Registered tool: read_csv – IMPORT A CSV AND CREATE A 'TABLE' ARTIFACT (COLUMNS + RECORDS). (modes=('DEFAULT',))
# 🧩 Registered tool: read_leveled_csv – IMPORTS A LEVELED CSV FILE AND CREATES A HIERARCHY ARTIFACT. (modes=('DEFAULT',))
# 🧩 Registered tool: read_workspace_memory – READS A SINGLE WORKSPACE MEMORY ITEM BY NAME AND RETURNS ITS STORED VALUE/METADATA. (modes=('DEFAULT',))
# 🧩 Registered tool: reason_and_publish_on_arcadia_fabric_files – Reason on an arcadia_fabric and/or file_reference artifacts using ChatGPTAnalyzer, then publish the result to disk (md + optional meta.json + optional html), modeled after execute_rag_publish. (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: reason_on_arcadia_fabric_or_files – Reason on an arcadia_fabric and/or file_reference artifacts using ChatGPTAnalyzer. (modes=('DEFAULT',))
# 🧩 Registered tool: render_prompt_artifact – Render a prompt_def using runtime variables and create a rendered prompt artifact. (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: save_prompt_def_artifact – Saves a rendered prompt definition as a prompt_def artifact and also persists a JSON prompt file to a prompt_path directory. (modes=('DEFAULT',))
# 🧩 Registered tool: search_prompts – LISTS PROMPTS WITHIN A PROMPT_PATH ARTIFACT, WITH OPTIONAL FILTERING. (modes=('DEFAULT',))
# 🧩 Registered tool: show_artifact – DISPLAY A STORED ARTIFACT (RAW CONTENT) BY ID, NAME, OR TYPE. (modes=('DEFAULT',))
# 🧩 Registered tool: show_artifact_memory – SUMMARIZE ARTIFACTS IN A PACKAGE WITH COUNTS AND EXAMPLES. Optional inputs: package_name (str), type_filter (str), max_names (int, default 8). (modes=('DEFAULT',))
# 🧩 Registered tool: show_prompt_spec – DISPLAYS A PROMPT_SPEC ARTIFACT WITH TITLE, VERSION, AND JSON PREVIEW. (modes=('DEFAULT',))
# 🧩 Registered tool: table_column_to_list – EXTRACT A COLUMN FROM A TABLE ARTIFACT AND CREATE A LIST ARTIFACT. (modes=('DEFAULT',))
# 🧩 Registered tool: upload_file_as_artifact – Upload a file and register it as a 'file_artifact' tied to an OpenAI vector store, then attach it to workspace memory. (modes=('DEFAULT',))
# 🧩 Registered tool: write_csv – Write a list of rows to a CSV file (source: input data or a 'table' artifact). (modes=('DEFAULT',))
# 🧩 Registered tool: write_leveled_csv – Write a hierarchical breakdown to CSV. Optionally add a column and persist updated hierarchy to artifacts. (modes=('DEFAULT',))
# [contract] Tool 'build_capella_model_embeddings' has remember-outputs ['embeddings_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'create_artifact' has remember-outputs ['artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'create_capella_model_artifact' has remember-outputs ['capella_model_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'create_folder_path' has remember-outputs ['folder_path_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'create_scaffold_artifact_for_tool' has remember-outputs ['artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'create_sysmlv2_snapshot_artifact' has remember-outputs ['sysmlv2_snapshot_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'execute_diagram_retrieve' has remember-outputs ['diagram_artifact_ids']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'execute_publish_diagram_retrieve' has remember-outputs ['diagram_artifact_ids']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'extract_word_tables_to_csv' has remember-outputs ['manifest_file_reference', 'csv_file_references']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'generate_sysmlv2_fabric' has remember-outputs ['file']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'llm_chat' has remember-outputs ['conversation_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'load_from_workspace_memory_to_artifact' has remember-outputs ['artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'load_prompt_path' has remember-outputs ['prompt_path_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'query_capella_embeddings' has remember-outputs ['table_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'read_csv' has remember-outputs ['table_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'read_leveled_csv' has remember-outputs ['hierarchy_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'read_workspace_memory' has remember-outputs ['name', 'type', 'origin_artifact_id', 'value']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'table_column_to_list' has remember-outputs ['list_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'upload_file_as_artifact' has remember-outputs ['file']. Ensure it returns result['artifact_ids'][name] on success.
# input data: {'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird', 'name': 'EBSD_300', 'resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}}
# ✅ Artifact created: name='_workspace_store' id='826b2dcf' type='workspace' in package 'SE_Solutions'
# resolved input: {'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird', 'name': 'EBSD_300', 'resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}}
# JIT Input: {'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird', 'name': 'EBSD_300', 'resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}}
# ✅ Artifact created: name='EBSD_300' id='da5ed699' type='capella_model' in package 'SE_Solutions'
# {'message': "✅ Created capella_model artifact 📋 from '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird'.",
#  'artifact_ids': {'capella_model_artifact_id': 'da5ed699-199d-4882-875c-8478b74d771d'},
#  'path': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird',
#  'named': True,
#  'artifact_message': "✅ Artifact created: name='_workspace_store' id='826b2dcf' type='workspace' in package 'SE_Solutions'"}

# %%
res = agent.act('/t load_prompt_path prompt_dir_path :  "/home/simcenter/studio/EBSD_300/EBSD_300/Notebooks/prompt_library" , Name:  "prompt_dir_path" ')
#from pprint import pprint; pprint(res)
# Out:
# ✅ Planned tool actions now executing:
#
# {"actions":[{"tool":"load_prompt_path","input":{"prompt_dir_path":"/home/simcenter/studio/knowledge_partner/prompt_library/","name":"prompt_dir_path"}}]}
# ✅ Prompt path loaded as artifact📋: id='96e2eb9c' (2 notebooks)

# %%
res = agent.act('/t create_artifact of type prompt it name should be Requirement and it content should be  "[LAB] Requirements"')
#from pprint import pprint; pprint(res)
# Out:
# ✅ Planned tool actions now executing:
#
# {"actions":[{"tool":"create_artifact","input":{"name":"Requirement","type":"prompt","content":"[LAB] Requirements"}}]}
# **Created**: `Requirement`<br><i>(type: prompt, package: SE_Solutions)</i>

# %%
#Start interactive chat with file attach + artifact capture
# Call chat as a tool
#agent.run("interactive_chat", input_data={    "context": "You are a systems engineering assistant."}, agent=agent)

# %%
res = agent.act('/t build_capella_model_embeddings capella_model: {"type": "capella_model", "name": "EBSD_300" }')
#from pprint import pprint; pprint(res)
# Out:
# ✅ Planned tool actions now executing:
#
# {"actions":[{"tool":"build_capella_model_embeddings","input":{"capella_model":{"type":"capella_model","name":"EBSD_300"}}}]}
# ✅ Embeddings built and registered (bb9f5656)

# %%
res = agent.act('/t query_capella_embeddings EBSD_300_emb with prompt artifact name ="Requirements" return to 1 ')
#from pprint import pprint; pprint(res)
# Out:
# ✅ Planned tool actions now executing:
#
# {"actions":[{"tool":"query_capella_embeddings","input":{"embeddings":{"type":"embeddings","name":"EBSD_300_emb"},"prompt":{"type":"prompt","name":"Requirement"},"top_n":1}}]}
# ✅ Query completed: 1 row(s)

# %%
res = agent.act("/t table column to list  colume: uuid name the list EBSD_300_uuids")
#from pprint import pprint; pprint(res)
#Start interactive chat with file attach + artifact capture
# Call chat as a tool
#agent.run("interactive_chat", input_data={
#    "context": "You are a systems engineering assistant."
#}, agent=agent)
# Out:
# ✅ Planned tool actions now executing:
#
# {"actions":[{"tool":"table_column_to_list","input":{"table":{"type":"table"},"column":"uuid","name":"EBSD_300_uuids"}}]}
# ✅ List extracted: 1 unique value(s)

# %%
res = agent.act('/t generate_arcadia_fabric capella_model: {"type": "capella_model", "name": "EBSD_300" }, targets_list: {"type": "list", "name": "EBSD_300_uuids"}')
#from pprint import pprint; pprint(res)
# Out:
# ✅ Planned tool actions now executing:
#
# {"actions":[{"tool":"generate_arcadia_fabric","input":{"capella_model":{"type":"capella_model","name":"EBSD_300"},"targets_list":{"type":"list","name":"EBSD_300_uuids"}}}]}
# ✅ Fabric created (1 object(s))

# %%
res = agent.act('/t load_prompt_def_artifact prompt_title: "Capella_Requirement" prompt_dir_ref: prompt_dir_path' )
#from pprint import pprint; pprint(res)
# Out:
# ✅ Planned tool actions now executing:
#
# {"actions":[{"tool":"load_prompt_def_artifact","input":{"prompt_title":"Capella_Requirement","prompt_dir_ref":{"type":"prompt_path","name":"prompt_dir_path"}}}]}
# ✅ Prompt_def 'Capella_Requirement' created in package 'SE_Solutions'.

# %%
res = agent.act('/t render_prompt_artifact {"prompt_def": {"type":"prompt_def", "name":"Capella_Requirement"}, output_name: "Capella_Requirment_Rend" }')
#from pprint import pprint; pprint(res)
# Out:
# ✅ Planned tool actions now executing:
#
# {"actions":[{"tool":"render_prompt_artifact","input":{"prompt_def":{"type":"prompt_def","name":"Capella_Requirement"},"output_name":"Capella_Requirment_Rend"}}]}

# %%
res = agent.act('/t reason_on_arcadia_fabric_or_files using arcadia_fabric_fab and prompt Capella_Requirment_Rend' )
#res = agent.act('/t reason_and_publish_on_arcadia_fabric_files output_dir=./reports arcadia_fabric_name=arcadia_fabric_fab  prompt= Capella_Requirment_Rend')
# Out:
# ✅ Planned tool actions now executing:
#
# {"actions":[{"tool":"reason_on_arcadia_fabric_or_files","input":{"arcadia_fabric_name":"arcadia_fabric_fab","prompt_name":"Capella_Requirment_Rend"}}]}
# **Your prompt:** Please analyze the yaml file and display all Requirements for the diagram:
# 1. Format the requirement in a table.
# 2. Include its prefix, name, long_name, text, its relations and relation target. Format the response in .html format.
# ```html
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>System Requirements Table</title>
#
# </head>
# <body>
# <h2>System Requirements</h2>
# <table>
# <thead>
# <tr>
# <th>Prefix</th>
# <th>Name</th>
# <th>Long Name</th>
# <th>Text</th>
# <th>Relations</th>
# <th>Relation Target</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>REQ-000062/A</td>
# <td>Provide Storage Capabilities</td>
# <td>Provide Storage Capabilities</td>
# <td class="text-cell">The EBSD system shall provide mass storage for programs and data. It should be able to transfer data to and from mass storage devices, subject only to size limitations.</td>
# <td>Satisfy</td>
# <td class="target-cell">EBSD</td>
# </tr>
# <tr>
# <td>REQ-000057/A</td>
# <td>Provide Execution Capabilities</td>
# <td>Provide Execution Capabilities</td>
# <td class="text-cell">EBSD PC shall be Specific user’s EBSD PC hardware/software system configuration execution capability requirements the responsibility of the user.</td>
# <td>Satisfy</td>
# <td class="target-cell">EBSD</td>
# </tr>
# <tr>
# <td>REQ-000052/A</td>
# <td>Operating Pressure Environment</td>
# <td>Operating Pressure Environment</td>
# <td class="text-cell">The EBSD shall meet performance requirements specified herein during exposure to an ambient pressure environment ranging from 9.5 to 16.0 pounds per square inch absolute (psia).</td>
# <td>Satisfy</td>
# <td class="target-cell">EBSD</td>
# </tr>
# <tr>
# <td>REQ-000059/A</td>
# <td>Pressure Environment</td>
# <td>Pressure Environment</td>
# <td class="text-cell">The EBSD System hardware components shall meet performance requirements specified herein following exposure to the nominal pressure environments.</td>
# <td>Satisfy</td>
# <td class="target-cell">EBSD</td>
# </tr>
# <tr>
# <td>REQ-000053/A</td>
# <td>Vibration</td>
# <td>Vibration</td>
# <td class="text-cell">The EBSD hardware components shall comply with 1g</td>
# <td>Satisfy</td>
# <td class="target-cell">EBSD</td>
# </tr>
# <tr>
# <td>REQ-000068/A</td>
# <td>Enriched Oxygen Environment</td>
# <td>Enriched Oxygen Environment</td>
# <td class="text-cell">The EBSD hardware components shall meet specified performance when the atmosphere is at 10.2 +/- 0.2 psia with an oxygen concentration of up to 30 percent.</td>
# <td>Satisfy</td>
# <td class="target-cell">EBSD</td>
# </tr>
# <tr>
# <td>REQ-000071/A</td>
# <td>Humidity</td>
# <td>Humidity</td>
# <td class="text-cell">The EBSD hardware components shall meet the performance requirements specified herein when exposed to 30..90% (noncondensing) percent relative humidity</td>
# <td>Satisfy</td>
# <td class="target-cell">EBSD</td>
# </tr>
# <tr>
# <td>REQ-000056/A</td>
# <td>Shock</td>
# <td>Shock</td>
# <td class="text-cell">The EBSD hardware components shall meet 15g shock requirement</td>
# <td>Satisfy</td>
# <td class="target-cell">EBSD</td>
# </tr>
# <tr>
# <td>REQ-000050/A</td>
# <td>Operating Thermal Environment</td>
# <td>Operating Thermal Environment</td>
# <td class="text-cell">EBSD System shall operate between 0 and 50 °C</td>
# <td>Satisfy</td>
# <td class="target-cell">EBSD</td>
# </tr>
# <tr>
# <td>REQ-000063/A</td>
# <td>Ionizing Radiation</td>
# <td>Ionizing Radiation</td>
# <td class="text-cell">The EBSD hardware components shall meet specified performance when exposed to the nominal Single Event Effects (SEE) environment defined in the End Item Specification - MJ070-0001-1E, Performance &amp; Design Rqmts, Sections: 3.5.20Avionics Radiation Requirements and 10.1.7 Radiation.</td>
# <td>Satisfy</td>
# <td class="target-cell">EBSD</td>
# </tr>
# <tr>
# <td>REQ-000067/A</td>
# <td>Rear Panel Connections</td>
# <td>Rear Panel Connections</td>
# <td class="text-cell">Rear Panel Connections shall beat the back of the box.</td>
# <td>Satisfy</td>
# <td class="target-cell">Chassis Subsystem</td>
# </tr>
# <tr>
# <td>REQ-000058/A</td>
# <td>28 pin I/O interface</td>
# <td>28 pin I/O interface</td>
# <td class="text-cell">The EBSD System shall have 1 28 pin I/O interface</td>
# <td>Satisfy</td>
# <td class="target-cell">Chassis Subsystem</td>
# </tr>
# <tr>
# <td>REQ-000070/A</td>
# <td>Design</td>
# <td>Design</td>
# <td class="text-cell">The design of the EBSD PC shall fulfill / communicate: Robustness, High quality, Brand recognition, Ready for customizing, Color scheme to Siemens corporate colors.</td>
# <td>Satisfy</td>
# <td class="target-cell">EBSD</td>
# </tr>
# <tr>
# <td>REQ-000072/A</td>
# <td>Failure Propagation</td>
# <td>Failure Propagation</td>
# <td class="text-cell">Simcenter EBSD PC COTS hardware shall be analyzed to determine its intrinsic failure propagation capabilities. Failure propagations for specific hardware/software system configuration of data systems will be addressed in the features specification.</td>
# <td>Satisfy</td>
# <td class="target-cell">EBSD</td>
# </tr>
# <tr>
# <td>REQ-000055/A</td>
# <td>Failure Tolerance</td>
# <td>Failure Tolerance</td>
# <td class="text-cell">Simcenter EBSD PC software system configuration requirements for failure tolerance levels shall be address in the features specification.</td>
# <td>Satisfy</td>
# <td class="target-cell">EBSD</td>
# </tr>
# <tr>
# <td>REQ-000069/A</td>
# <td>Screening for Early Failure</td>
# <td>Screening for Early Failure</td>
# <td class="text-cell">Simcenter EBSD PC hardware shall be submitted to burn-in testing to detect material and workmanship defects, which can result in early component failure.</td>
# <td>Satisfy</td>
# <td class="target-cell">EBSD</td>
# </tr>
# <tr>
# <td>REQ-000066/A</td>
# <td>Power</td>
# <td>Power</td>
# <td class="text-cell">Maximum power consumption shall be 430 W</td>
# <td>Satisfy</td>
# <td class="target-cell">Power Subsytem, AC/DC Power Supply</td>
# </tr>
# <tr>
# <td>REQ-000143/A</td>
# <td>Efficiency</td>
# <td>Efficiency</td>
# <td class="text-cell">The Power Subsystem shall transform power efficiently of higher than 80%..</td>
# <td>Satisfy</td>
# <td class="target-cell">Power Subsytem</td>
# </tr>
# <tr>
# <td>REQ-000141/A</td>
# <td>Temo Variation</td>
# <td>Temo Variation</td>
# <td class="text-cell">The Power Subsystem shall handle environmental impacts such as temperature variations.</td>
# <td>Satisfy</td>
# <td class="target-cell">Power Subsytem</td>
# </tr>
# <tr>
# <td>REQ-000147/A</td>
# <td>Power Conversion</td>
# <td>Power Conversion</td>
# <td class="text-cell">The Power Subsystem shall convert power supply to compatible voltages for all subsystems.</td>
# <td>Satisfy</td>
# <td class="target-cell">Power Subsytem</td>
# </tr>
# <tr>
# <td>REQ-000146/A</td>
# <td>Stability</td>
# <td>Stability</td>
# <td class="text-cell">The Power Subsystem shall manage load distribution for system stability.</td>
# <td>Satisfy</td>
# <td class="target-cell">Power Subsytem</td>
# </tr>
# <tr>
# <td>REQ-000142/A</td>
# <td>Distribute Power</td>
# <td>Distribute Power</td>
# <td class="text-cell">The Power Subsystem shall distribute power to all necessary components.</td>
# <td>Satisfy</td>
# <td class="target-cell">Power Subsytem</td>
# </tr>
# <tr>
# <td>REQ-000144/A</td>
# <td>Power Storage</td>
# <td>Power Storage</td>
# <td class="text-cell">The Power Subsystem shall support energy storage to handle less than 10 second power drops</td>
# <td>Satisfy</td>
# <td class="target-cell">Power Subsytem</td>
# </tr>
# <tr>
# <td>REQ-000145/A</td>
# <td>Isolation</td>
# <td>Isolation</td>
# <td class="text-cell">The Power Subsystem shall provide isolation in case of power faults.</td>
# <td>Satisfy</td>
# <td class="target-cell">Power Subsytem</td>
# </tr>
# <tr>
# <td>REQ-000061/A</td>
# <td>Usability</td>
# <td>Usability</td>
# <td class="text-cell">All interfaces and control elements shall be on one side; easy accessibility / usability to interfaces and control elements in standard mounting.</td>
# <td>Satisfy</td>
# <td class="target-cell">Chassis Subsystem</td>
# </tr>
# <tr>
# <td>REQ-000060/A</td>
# <td>Diagnosis</td>
# <td>Diagnosis</td>
# <td class="text-cell">The EBSD system shall have an embedded monitoring capability of the main board temperature</td>
# <td>Satisfy</td>
# <td class="target-cell">Control Subsystem, EBSD</td>
# </tr>
# <tr>
# <td>REQ-000076/A</td>
# <td>Fanless CPU Cooling</td>
# <td>Fanless CPU Cooling</td>
# <td class="text-cell">The EBSD System shall have heat-sink with no fans on CPU</
# **Token Usage Info:**
#
# Tokens used: prompt=112812, completion=17058, total=129870

# %%
res = agent.act('/t write_csv of the table from the message response name it EBSD_Requirements')
from pprint import pprint; pprint(res)
#res = agent.act('/t write_csv artifact "product_requirements" to file_name "product_requirement.csv"')
#from pprint import pprint; pprint(res)
# Out:
# ✅ Planned tool actions now executing:
#
# {"actions":[{"tool":"write_csv","input":{"filename":"EBSD_Requirements.csv","data":[{"Prefix":"REQ-000062/A","Name":"Provide Storage Capabilities","Long Name":"Provide Storage Capabilities","Text":"The EBSD system shall provide mass storage for programs and data. It should be able to transfer data to and from mass storage devices, subject only to size limitations.","Relations":"Satisfy","Relation Target":"EBSD"},{"Prefix":"REQ-000057/A","Name":"Provide Execution Capabilities","Long Name":"Provide Execution Capabilities","Text":"EBSD PC shall be Specific user's EBSD PC hardware/software system configuration execution capability requirements the responsibility of the user.","Relations":"Satisfy","Relation Target":"EBSD"},{"Prefix":"REQ-000052/A","Name":"Operating Pressure Environment","Long Name":"Operating Pressure Environment","Text":"The EBSD shall meet performance requirements specified herein during exposure to an ambient pressure environment ranging from 9.5 to 16.0 pounds per square inch absolute (psia).","Relations":"Satisfy","Relation Target":"EBSD"},{"Prefix":"REQ-000059/A","Name":"Pressure Environment","Long Name":"Pressure Environment","Text":"The EBSD System hardware components shall meet performance requirements specified herein following exposure to the nominal pressure environments.","Relations":"Satisfy","Relation Target":"EBSD"},{"Prefix":"REQ-000053/A","Name":"Vibration","Long Name":"Vibration","Text":"The EBSD hardware components shall comply with 1g","Relations":"Satisfy","Relation Target":"EBSD"},{"Prefix":"REQ-000068/A","Name":"Enriched Oxygen Environment","Long Name":"Enriched Oxygen Environment","Text":"The EBSD hardware components shall meet specified performance when the atmosphere is at 10.2 +/- 0.2 psia with an oxygen concentration of up to 30 percent.","Relations":"Satisfy","Relation Target":"EBSD"},{"Prefix":"REQ-000071/A","Name":"Humidity","Long Name":"Humidity","Text":"The EBSD hardware components shall meet the performance requirements specified herein when exposed to 30..90% (noncondensing) percent relative humidity","Relations":"Satisfy","Relation Target":"EBSD"},{"Prefix":"REQ-000056/A","Name":"Shock","Long Name":"Shock","Text":"The EBSD hardware components shall meet 15g shock requirement","Relations":"Satisfy","Relation Target":"EBSD"},{"Prefix":"REQ-000050/A","Name":"Operating Thermal Environment","Long Name":"Operating Thermal Environment","Text":"EBSD System shall operate between 0 and 50 °C","Relations":"Satisfy","Relation Target":"EBSD"},{"Prefix":"REQ-000063/A","Name":"Ionizing Radiation","Long Name":"Ionizing Radiation","Text":"The EBSD hardware components shall meet specified performance when exposed to the nominal Single Event Effects (SEE) environment defined in the End Item Specification - MJ070-0001-1E, Performance & Design Rqmts, Sections: 3.5.20Avionics Radiation Requirements and 10.1.7 Radiation.","Relations":"Satisfy","Relation Target":"EBSD"},{"Prefix":"REQ-000067/A","Name":"Rear Panel Connections","Long Name":"Rear Panel Connections","Text":"Rear Panel Connections shall beat the back of the box.","Relations":"Satisfy","Relation Target":"Chassis Subsystem"},{"Prefix":"REQ-000058/A","Name":"28 pin I/O interface","Long Name":"28 pin I/O interface","Text":"The EBSD System shall have 1 28 pin I/O interface","Relations":"Satisfy","Relation Target":"Chassis Subsystem"},{"Prefix":"REQ-000070/A","Name":"Design","Long Name":"Design","Text":"The design of the EBSD PC shall fulfill / communicate: Robustness, High quality, Brand recognition, Ready for customizing, Color scheme to Siemens corporate colors.","Relations":"Satisfy","Relation Target":"EBSD"},{"Prefix":"REQ-000072/A","Name":"Failure Propagation","Long Name":"Failure Propagation","Text":"Simcenter EBSD PC COTS hardware shall be analyzed to determine its intrinsic failure propagation capabilities. Failure propagations for specific hardware/software system configuration of data systems will be addressed in the features specific ...
# 💾 Export completed via 'write_csv'.
# {'llm_result': {'artifact_ids': {'conversation_artifact_id': 'af0d312a-e18d-4b58-bf66-5299f6ae9d8b'},
#                 'message': '✅ Chat completed.',
#                 'model': 'qwen-3.6-27b',
#                 'response': '\n'
#                             '\n'
#                             '{"actions":[{"tool":"write_csv","input":{"filename":"EBSD_Requirements.csv","data":[{"Prefix":"REQ-000062/A","Name":"Provide '
#                             'Storage Capabilities","Long Name":"Provide '
#                             'Storage Capabilities","Text":"The EBSD system '
#                             'shall provide mass storage for programs and data. '
#                             'It should be able to transfer data to and from '
#                             'mass storage devices, subject only to size '
#                             'limitations.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000057/A","Name":"Provide '
#                             'Execution Capabilities","Long Name":"Provide '
#                             'Execution Capabilities","Text":"EBSD PC shall be '
#                             "Specific user's EBSD PC hardware/software system "
#                             'configuration execution capability requirements '
#                             'the responsibility of the '
#                             'user.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000052/A","Name":"Operating '
#                             'Pressure Environment","Long Name":"Operating '
#                             'Pressure Environment","Text":"The EBSD shall meet '
#                             'performance requirements specified herein during '
#                             'exposure to an ambient pressure environment '
#                             'ranging from 9.5 to 16.0 pounds per square inch '
#                             'absolute (psia).","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000059/A","Name":"Pressure '
#                             'Environment","Long Name":"Pressure '
#                             'Environment","Text":"The EBSD System hardware '
#                             'components shall meet performance requirements '
#                             'specified herein following exposure to the '
#                             'nominal pressure '
#                             'environments.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000053/A","Name":"Vibration","Long '
#                             'Name":"Vibration","Text":"The EBSD hardware '
#                             'components shall comply with '
#                             '1g","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000068/A","Name":"Enriched '
#                             'Oxygen Environment","Long Name":"Enriched Oxygen '
#                             'Environment","Text":"The EBSD hardware components '
#                             'shall meet specified performance when the '
#                             'atmosphere is at 10.2 +/- 0.2 psia with an oxygen '
#                             'concentration of up to 30 '
#                             'percent.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000071/A","Name":"Humidity","Long '
#                             'Name":"Humidity","Text":"The EBSD hardware '
#                             'components shall meet the performance '
#                             'requirements specified herein when exposed to '
#                             '30..90% (noncondensing) percent relative '
#                             'humidity","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000056/A","Name":"Shock","Long '
#                             'Name":"Shock","Text":"The EBSD hardware '
#                             'components shall meet 15g shock '
#                             'requirement","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000050/A","Name":"Operating '
#                             'Thermal Environment","Long Name":"Operating '
#                             'Thermal Environment","Text":"EBSD System shall '
#                             'operate between 0 and 50 '
#                             '°C","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000063/A","Name":"Ionizing '
#                             'Radiation","Long Name":"Ionizing '
#                             'Radiation","Text":"The EBSD hardware components '
#                             'shall meet specified performance when exposed to '
#                             'the nominal Single Event Effects (SEE) '
#                             'environment defined in the End Item Specification '
#                             '- MJ070-0001-1E, Performance & Design Rqmts, '
#                             'Sections: 3.5.20Avionics Radiation Requirements '
#                             'and 10.1.7 '
#                             'Radiation.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000067/A","Name":"Rear '
#                             'Panel Connections","Long Name":"Rear Panel '
#                             'Connections","Text":"Rear Panel Connections shall '
#                             'beat the back of the '
#                             'box.","Relations":"Satisfy","Relation '
#                             'Target":"Chassis '
#                             'Subsystem"},{"Prefix":"REQ-000058/A","Name":"28 '
#                             'pin I/O interface","Long Name":"28 pin I/O '
#                             'interface","Text":"The EBSD System shall have 1 '
#                             '28 pin I/O '
#                             'interface","Relations":"Satisfy","Relation '
#                             'Target":"Chassis '
#                             'Subsystem"},{"Prefix":"REQ-000070/A","Name":"Design","Long '
#                             'Name":"Design","Text":"The design of the EBSD PC '
#                             'shall fulfill / communicate: Robustness, High '
#                             'quality, Brand recognition, Ready for '
#                             'customizing, Color scheme to Siemens corporate '
#                             'colors.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000072/A","Name":"Failure '
#                             'Propagation","Long Name":"Failure '
#                             'Propagation","Text":"Simcenter EBSD PC COTS '
#                             'hardware shall be analyzed to determine its '
#                             'intrinsic failure propagation capabilities. '
#                             'Failure propagations for specific '
#                             'hardware/software system configuration of data '
#                             'systems will be addressed in the features '
#                             'specification.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000055/A","Name":"Failure '
#                             'Tolerance","Long Name":"Failure '
#                             'Tolerance","Text":"Simcenter EBSD PC software '
#                             'system configuration requirements for failure '
#                             'tolerance levels shall be address in the features '
#                             'specification.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000069/A","Name":"Screening '
#                             'for Early Failure","Long Name":"Screening for '
#                             'Early Failure","Text":"Simcenter EBSD PC hardware '
#                             'shall be submitted to burn-in testing to detect '
#                             'material and workmanship defects, which can '
#                             'result in early component '
#                             'failure.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000066/A","Name":"Power","Long '
#                             'Name":"Power","Text":"Maximum power consumption '
#                             'shall be 430 W","Relations":"Satisfy","Relation '
#                             'Target":"Power Subsytem, AC/DC Power '
#                             'Supply"},{"Prefix":"REQ-000143/A","Name":"Efficiency","Long '
#                             'Name":"Efficiency","Text":"The Power Subsystem '
#                             'shall transform power efficiently of higher than '
#                             '80%..","Relations":"Satisfy","Relation '
#                             'Target":"Power '
#                             'Subsytem"},{"Prefix":"REQ-000141/A","Name":"Temo '
#                             'Variation","Long Name":"Temo '
#                             'Variation","Text":"The Power Subsystem shall '
#                             'handle environmental impacts such as temperature '
#                             'variations.","Relations":"Satisfy","Relation '
#                             'Target":"Power '
#                             'Subsytem"},{"Prefix":"REQ-000147/A","Name":"Power '
#                             'Conversion","Long Name":"Power '
#                             'Conversion","Text":"The Power Subsystem shall '
#                             'convert power supply to compatible voltages for '
#                             'all subsystems.","Relations":"Satisfy","Relation '
#                             'Target":"Power '
#                             'Subsytem"},{"Prefix":"REQ-000146/A","Name":"Stability","Long '
#                             'Name":"Stability","Text":"The Power Subsystem '
#                             'shall manage load distribution for system '
#                             'stability.","Relations":"Satisfy","Relation '
#                             'Target":"Power '
#                             'Subsytem"},{"Prefix":"REQ-000142/A","Name":"Distribute '
#                             'Power","Long Name":"Distribute Power","Text":"The '
#                             'Power Subsystem shall distribute power to all '
#                             'necessary '
#                             'components.","Relations":"Satisfy","Relation '
#                             'Target":"Power '
#                             'Subsytem"},{"Prefix":"REQ-000144/A","Name":"Power '
#                             'Storage","Long Name":"Power Storage","Text":"The '
#                             'Power Subsystem shall support energy storage to '
#                             'handle less than 10 second power '
#                             'drops","Relations":"Satisfy","Relation '
#                             'Target":"Power '
#                             'Subsytem"},{"Prefix":"REQ-000145/A","Name":"Isolation","Long '
#                             'Name":"Isolation","Text":"The Power Subsystem '
#                             'shall provide isolation in case of power '
#                             'faults.","Relations":"Satisfy","Relation '
#                             'Target":"Power '
#                             'Subsytem"},{"Prefix":"REQ-000061/A","Name":"Usability","Long '
#                             'Name":"Usability","Text":"All interfaces and '
#                             'control elements shall be on one side; easy '
#                             'accessibility / usability to interfaces and '
#                             'control elements in standard '
#                             'mounting.","Relations":"Satisfy","Relation '
#                             'Target":"Chassis '
#                             'Subsystem"},{"Prefix":"REQ-000060/A","Name":"Diagnosis","Long '
#                             'Name":"Diagnosis","Text":"The EBSD system shall '
#                             'have an embedded monitoring capability of the '
#                             'main board '
#                             'temperature","Relations":"Satisfy","Relation '
#                             'Target":"Control Subsystem, '
#                             'EBSD"},{"Prefix":"REQ-000076/A","Name":"Fanless '
#                             'CPU Cooling","Long Name":"Fanless CPU '
#                             'Cooling","Text":"The EBSD System shall have '
#                             'heat-sink with no fans on '
#                             'CPU","Relations":"Satisfy","Relation '
#                             'Target":"EBSD, '
#                             'Fan"},{"Prefix":"REQ-000065/A","Name":"Provide '
#                             'Startup Capabilities","Long Name":"Provide '
#                             'Startup Capabilities","Text":"EBSD System EBSD PC '
#                             'shall initialize and perform internal tests as '
#                             'provided by the COTS components, and will provide '
#                             'feedback.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000064/A","Name":"Provide '
#                             'File Transfer Capabilities","Long Name":"Provide '
#                             'File Transfer Capabilities","Text":"EBSD System '
#                             "shall be specific user's EBSD PC "
#                             'hardware/software system configuration '
#                             'requirements to transfer files are the '
#                             'responsibility of the user. The Simcenter EBSD PC '
#                             'support the transfer of files using the following '
#                             'USB connector (V2.0), LAN, '
#                             'Wireless","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000049/A","Name":"Provide '
#                             'Caution and Warning Capabilities","Long '
#                             'Name":"Provide Caution and Warning '
#                             'Capabilities","Text":"EBSD System shall capture '
#                             "specific user's EBSD PC hardware/software system "
#                             'configuration requirements for caution and '
#                             'warning functionality are the responsibility of '
#                             'the user.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000051/A","Name":"Receive '
#                             'and Process External Data","Long Name":"Receive '
#                             'and Process External Data","Text":"EBSD System '
#                             "shall capture specific user's EBSD PC "
#                             'hardware/software system configuration '
#                             'requirements for receiving and processing data '
#                             'are the responsibility of the '
#                             'users.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000054/A","Name":"Provide '
#                             'Communication Capabilities","Long Name":"Provide '
#                             'Communication Capabilities","Text":"EBSD System '
#                             "shall capture specific user's hardware/software "
#                             'system configuration requirements to transfer '
#                             'files are out of scope of this PTRS. The EBSD PC '
#                             'support the transfer of data for communication '
#                             'with the following interfaces: USB connector '
#                             '(V2.0)","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000156/A","Name":"Baseline '
#                             'Test Performance","Long Name":"Baseline Test '
#                             'Performance","Text":"The EBSD System shall '
#                             'perform baseline performance test in 90 '
#                             'seconds.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD, Control Subsystem, PCB '
#                             'SC100"},{"Prefix":"REQ-000155/A","Name":"CAN","Long '
#                             'Name":"CAN","Text":"The EBSD System shall have 5 '
#                             'CAN connections","Relations":"Satisfy","Relation '
#                             'Target":"Chassis Subsystem, '
#                             'EBSD"},{"Prefix":"REQ-000163/A","Name":"EBSD '
#                             'junction operating temperatures","Long '
#                             'Name":"EBSD junction operating '
#                             'temperatures","Text":"The operating temperature '
#                             'on boards shall not exceed 70° '
#                             'C.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD, Control '
#                             'Subsystem"},{"Prefix":"REQ-000160/A","Name":"Service","Long '
#                             'Name":"Service","Text":"The EBSD system shall be '
#                             'capable of service with standard shop '
#                             'tools.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000162/A","Name":"EBSD '
#                             'board temperatures","Long Name":"EBSD board '
#                             'temperatures","Text":"The EBSD board temperatures '
#                             'shall be '
#                             'monitored.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD, Control '
#                             'Subsystem"},{"Prefix":"REQ-000165/A","Name":"Component '
#                             'Costs","Long Name":"Component Costs","Text":"The '
#                             'EBSD component cost shall not exceed 1500 '
#                             'USD.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000166/A","Name":"Per '
#                             'Unit Assembly Costs","Long Name":"Per Unit '
#                             'Assembly Costs","Text":"The EBSD component cost '
#                             'shall not exceed 500 '
#                             'USD.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000151/A","Name":"Gigabit '
#                             'Ethernet port","Long Name":"Gigabit Ethernet '
#                             'port","Text":"The EBSD System shall have 1 '
#                             'Gigabit Ethernet '
#                             'port.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000153/A","Name":"RS232","Long '
#                             'Name":"RS232","Text":"The EBSD System shall 3 '
#                             'RS232 ports.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000154/A","Name":"RS422/485","Long '
#                             'Name":"RS422/485","Text":"The EBSD System shall '
#                             'have 1 RS422/485 '
#                             'ports.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"},{"Prefix":"REQ-000152/A","Name":"USB '
#                             '- A","Long Name":"USB - A","Text":"The EBSD '
#                             'System shall have two USB A '
#                             'ports.","Relations":"Satisfy","Relation '
#                             'Target":"EBSD, PCB '
#                             'SC100"},{"Prefix":"REQ-000159/A","Name":"USB '
#                             'Connector (V2.0)","Long Name":"USB Connector '
#                             '(V2.0)","Text":"EBSD System shall have USB 2.0 '
#                             'Connector on the Front Panel for mass storage of '
#                             'data.","Relations":"Satisfy","Relation '
#                             'Target":"Structure, '
#                             'EBSD"},{"Prefix":"REQ-000169/A","Name":"Fiber '
#                             'Optic RX/TX","Long Name":"Fiber Optic '
#                             'RX/TX","Text":"The EBSD System hall have 1 Fiber '
#                             'Optic RX/TX port","Relations":"Satisfy","Relation '
#                             'Target":"EBSD"}]}}]'},
#  'mode': 'executed_actions',
#  'response': '\n'
#              '\n'
#              '{"actions":[{"tool":"write_csv","input":{"filename":"EBSD_Requirements.csv","data":[{"Prefix":"REQ-000062/A","Name":"Provide '
#              'Storage Capabilities","Long Name":"Provide Storage '
#              'Capabilities","Text":"The EBSD system shall provide mass storage '
#              'for programs and data. It should be able to transfer data to and '
#              'from mass storage devices, subject only to size '
#              'limitations.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000057/A","Name":"Provide '
#              'Execution Capabilities","Long Name":"Provide Execution '
#              'Capabilities","Text":"EBSD PC shall be Specific user\'s EBSD PC '
#              'hardware/software system configuration execution capability '
#              'requirements the responsibility of the '
#              'user.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000052/A","Name":"Operating '
#              'Pressure Environment","Long Name":"Operating Pressure '
#              'Environment","Text":"The EBSD shall meet performance '
#              'requirements specified herein during exposure to an ambient '
#              'pressure environment ranging from 9.5 to 16.0 pounds per square '
#              'inch absolute (psia).","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000059/A","Name":"Pressure '
#              'Environment","Long Name":"Pressure Environment","Text":"The EBSD '
#              'System hardware components shall meet performance requirements '
#              'specified herein following exposure to the nominal pressure '
#              'environments.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000053/A","Name":"Vibration","Long '
#              'Name":"Vibration","Text":"The EBSD hardware components shall '
#              'comply with 1g","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000068/A","Name":"Enriched Oxygen '
#              'Environment","Long Name":"Enriched Oxygen '
#              'Environment","Text":"The EBSD hardware components shall meet '
#              'specified performance when the atmosphere is at 10.2 +/- 0.2 '
#              'psia with an oxygen concentration of up to 30 '
#              'percent.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000071/A","Name":"Humidity","Long '
#              'Name":"Humidity","Text":"The EBSD hardware components shall meet '
#              'the performance requirements specified herein when exposed to '
#              '30..90% (noncondensing) percent relative '
#              'humidity","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000056/A","Name":"Shock","Long '
#              'Name":"Shock","Text":"The EBSD hardware components shall meet '
#              '15g shock requirement","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000050/A","Name":"Operating '
#              'Thermal Environment","Long Name":"Operating Thermal '
#              'Environment","Text":"EBSD System shall operate between 0 and 50 '
#              '°C","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000063/A","Name":"Ionizing '
#              'Radiation","Long Name":"Ionizing Radiation","Text":"The EBSD '
#              'hardware components shall meet specified performance when '
#              'exposed to the nominal Single Event Effects (SEE) environment '
#              'defined in the End Item Specification - MJ070-0001-1E, '
#              'Performance & Design Rqmts, Sections: 3.5.20Avionics Radiation '
#              'Requirements and 10.1.7 '
#              'Radiation.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000067/A","Name":"Rear Panel '
#              'Connections","Long Name":"Rear Panel Connections","Text":"Rear '
#              'Panel Connections shall beat the back of the '
#              'box.","Relations":"Satisfy","Relation Target":"Chassis '
#              'Subsystem"},{"Prefix":"REQ-000058/A","Name":"28 pin I/O '
#              'interface","Long Name":"28 pin I/O interface","Text":"The EBSD '
#              'System shall have 1 28 pin I/O '
#              'interface","Relations":"Satisfy","Relation Target":"Chassis '
#              'Subsystem"},{"Prefix":"REQ-000070/A","Name":"Design","Long '
#              'Name":"Design","Text":"The design of the EBSD PC shall fulfill / '
#              'communicate: Robustness, High quality, Brand recognition, Ready '
#              'for customizing, Color scheme to Siemens corporate '
#              'colors.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000072/A","Name":"Failure '
#              'Propagation","Long Name":"Failure Propagation","Text":"Simcenter '
#              'EBSD PC COTS hardware shall be analyzed to determine its '
#              'intrinsic failure propagation capabilities. Failure propagations '
#              'for specific hardware/software system configuration of data '
#              'systems will be addressed in the features '
#              'specification.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000055/A","Name":"Failure '
#              'Tolerance","Long Name":"Failure Tolerance","Text":"Simcenter '
#              'EBSD PC software system configuration requirements for failure '
#              'tolerance levels shall be address in the features '
#              'specification.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000069/A","Name":"Screening for '
#              'Early Failure","Long Name":"Screening for Early '
#              'Failure","Text":"Simcenter EBSD PC hardware shall be submitted '
#              'to burn-in testing to detect material and workmanship defects, '
#              'which can result in early component '
#              'failure.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000066/A","Name":"Power","Long '
#              'Name":"Power","Text":"Maximum power consumption shall be 430 '
#              'W","Relations":"Satisfy","Relation Target":"Power Subsytem, '
#              'AC/DC Power '
#              'Supply"},{"Prefix":"REQ-000143/A","Name":"Efficiency","Long '
#              'Name":"Efficiency","Text":"The Power Subsystem shall transform '
#              'power efficiently of higher than '
#              '80%..","Relations":"Satisfy","Relation Target":"Power '
#              'Subsytem"},{"Prefix":"REQ-000141/A","Name":"Temo '
#              'Variation","Long Name":"Temo Variation","Text":"The Power '
#              'Subsystem shall handle environmental impacts such as temperature '
#              'variations.","Relations":"Satisfy","Relation Target":"Power '
#              'Subsytem"},{"Prefix":"REQ-000147/A","Name":"Power '
#              'Conversion","Long Name":"Power Conversion","Text":"The Power '
#              'Subsystem shall convert power supply to compatible voltages for '
#              'all subsystems.","Relations":"Satisfy","Relation Target":"Power '
#              'Subsytem"},{"Prefix":"REQ-000146/A","Name":"Stability","Long '
#              'Name":"Stability","Text":"The Power Subsystem shall manage load '
#              'distribution for system '
#              'stability.","Relations":"Satisfy","Relation Target":"Power '
#              'Subsytem"},{"Prefix":"REQ-000142/A","Name":"Distribute '
#              'Power","Long Name":"Distribute Power","Text":"The Power '
#              'Subsystem shall distribute power to all necessary '
#              'components.","Relations":"Satisfy","Relation Target":"Power '
#              'Subsytem"},{"Prefix":"REQ-000144/A","Name":"Power Storage","Long '
#              'Name":"Power Storage","Text":"The Power Subsystem shall support '
#              'energy storage to handle less than 10 second power '
#              'drops","Relations":"Satisfy","Relation Target":"Power '
#              'Subsytem"},{"Prefix":"REQ-000145/A","Name":"Isolation","Long '
#              'Name":"Isolation","Text":"The Power Subsystem shall provide '
#              'isolation in case of power '
#              'faults.","Relations":"Satisfy","Relation Target":"Power '
#              'Subsytem"},{"Prefix":"REQ-000061/A","Name":"Usability","Long '
#              'Name":"Usability","Text":"All interfaces and control elements '
#              'shall be on one side; easy accessibility / usability to '
#              'interfaces and control elements in standard '
#              'mounting.","Relations":"Satisfy","Relation Target":"Chassis '
#              'Subsystem"},{"Prefix":"REQ-000060/A","Name":"Diagnosis","Long '
#              'Name":"Diagnosis","Text":"The EBSD system shall have an embedded '
#              'monitoring capability of the main board '
#              'temperature","Relations":"Satisfy","Relation Target":"Control '
#              'Subsystem, EBSD"},{"Prefix":"REQ-000076/A","Name":"Fanless CPU '
#              'Cooling","Long Name":"Fanless CPU Cooling","Text":"The EBSD '
#              'System shall have heat-sink with no fans on '
#              'CPU","Relations":"Satisfy","Relation Target":"EBSD, '
#              'Fan"},{"Prefix":"REQ-000065/A","Name":"Provide Startup '
#              'Capabilities","Long Name":"Provide Startup '
#              'Capabilities","Text":"EBSD System EBSD PC shall initialize and '
#              'perform internal tests as provided by the COTS components, and '
#              'will provide feedback.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000064/A","Name":"Provide File '
#              'Transfer Capabilities","Long Name":"Provide File Transfer '
#              'Capabilities","Text":"EBSD System shall be specific user\'s EBSD '
#              'PC hardware/software system configuration requirements to '
#              'transfer files are the responsibility of the user. The Simcenter '
#              'EBSD PC support the transfer of files using the following USB '
#              'connector (V2.0), LAN, Wireless","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000049/A","Name":"Provide Caution '
#              'and Warning Capabilities","Long Name":"Provide Caution and '
#              'Warning Capabilities","Text":"EBSD System shall capture specific '
#              "user's EBSD PC hardware/software system configuration "
#              'requirements for caution and warning functionality are the '
#              'responsibility of the user.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000051/A","Name":"Receive and '
#              'Process External Data","Long Name":"Receive and Process External '
#              'Data","Text":"EBSD System shall capture specific user\'s EBSD PC '
#              'hardware/software system configuration requirements for '
#              'receiving and processing data are the responsibility of the '
#              'users.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000054/A","Name":"Provide '
#              'Communication Capabilities","Long Name":"Provide Communication '
#              'Capabilities","Text":"EBSD System shall capture specific user\'s '
#              'hardware/software system configuration requirements to transfer '
#              'files are out of scope of this PTRS. The EBSD PC support the '
#              'transfer of data for communication with the following '
#              'interfaces: USB connector '
#              '(V2.0)","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000156/A","Name":"Baseline Test '
#              'Performance","Long Name":"Baseline Test Performance","Text":"The '
#              'EBSD System shall perform baseline performance test in 90 '
#              'seconds.","Relations":"Satisfy","Relation Target":"EBSD, Control '
#              'Subsystem, PCB '
#              'SC100"},{"Prefix":"REQ-000155/A","Name":"CAN","Long '
#              'Name":"CAN","Text":"The EBSD System shall have 5 CAN '
#              'connections","Relations":"Satisfy","Relation Target":"Chassis '
#              'Subsystem, EBSD"},{"Prefix":"REQ-000163/A","Name":"EBSD junction '
#              'operating temperatures","Long Name":"EBSD junction operating '
#              'temperatures","Text":"The operating temperature on boards shall '
#              'not exceed 70° C.","Relations":"Satisfy","Relation '
#              'Target":"EBSD, Control '
#              'Subsystem"},{"Prefix":"REQ-000160/A","Name":"Service","Long '
#              'Name":"Service","Text":"The EBSD system shall be capable of '
#              'service with standard shop '
#              'tools.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000162/A","Name":"EBSD board '
#              'temperatures","Long Name":"EBSD board temperatures","Text":"The '
#              'EBSD board temperatures shall be '
#              'monitored.","Relations":"Satisfy","Relation Target":"EBSD, '
#              'Control Subsystem"},{"Prefix":"REQ-000165/A","Name":"Component '
#              'Costs","Long Name":"Component Costs","Text":"The EBSD component '
#              'cost shall not exceed 1500 USD.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000166/A","Name":"Per Unit '
#              'Assembly Costs","Long Name":"Per Unit Assembly '
#              'Costs","Text":"The EBSD component cost shall not exceed 500 '
#              'USD.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000151/A","Name":"Gigabit '
#              'Ethernet port","Long Name":"Gigabit Ethernet port","Text":"The '
#              'EBSD System shall have 1 Gigabit Ethernet '
#              'port.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000153/A","Name":"RS232","Long '
#              'Name":"RS232","Text":"The EBSD System shall 3 RS232 '
#              'ports.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000154/A","Name":"RS422/485","Long '
#              'Name":"RS422/485","Text":"The EBSD System shall have 1 RS422/485 '
#              'ports.","Relations":"Satisfy","Relation '
#              'Target":"EBSD"},{"Prefix":"REQ-000152/A","Name":"USB - A","Long '
#              'Name":"USB - A","Text":"The EBSD System shall have two USB A '
#              'ports.","Relations":"Satisfy","Relation Target":"EBSD, PCB '
#              'SC100"},{"Prefix":"REQ-000159/A","Name":"USB Connector '
#              '(V2.0)","Long Name":"USB Connector (V2.0)","Text":"EBSD System '
#              'shall have USB 2.0 Connector on the Front Panel for mass storage '
#              'of data.","Relations":"Satisfy","Relation Target":"Structure, '
#              'EBSD"},{"Prefix":"REQ-000169/A","Name":"Fiber Optic RX/TX","Long '
#              'Name":"Fiber Optic RX/TX","Text":"The EBSD System hall have 1 '
#              'Fiber Optic RX/TX port","Relations":"Satisfy","Relation '
#              'Target":"EBSD"}]}}]',
#  'tool_result': {'export_result': {'columns': ['Prefix',
#                                                'Name',
#                                                'Long Name',
#                                                'Text',
#                                                'Relations',
#                                                'Relation Target'],
#                                    'filename': 'EBSD_Requirements.csv',
#                                    'message': '📋 Wrote CSV to '
#                                               'EBSD_Requirements.csv',
#                                    'rows': 45},
#                  'message': "💾 Export completed via 'write_csv'."}}

# %%
#Start interactive chat with file attach + artifact capture
# Call chat as a tool
#agent.run("interactive_chat", input_data={
#    "context": "You are a systems engineering assistant."
#}, agent=agent)

# %%
pkg = agent.artifacts.get_active_package()
print([ (a.type, a.content) for a in pkg.artifacts.values() if a.type == "conversation"])

#agent.dump_chat_transcript("Run Transcript")

result = agent.run("notebook_export", input_data={"filename": "replay.ipynb"}, agent=agent)
# Out:
# [('conversation', {'prompt': '/t load_prompt_path prompt_dir_path : "/home/simcenter/studio/knowledge_partner/prompt_library/" , Name:  "prompt_dir_path"', 'response': '\n\n{"actions":[{"tool":"load_prompt_path","input":{"prompt_dir_path":"/home/simcenter/studio/knowledge_partner/prompt_library/","name":"prompt_dir_path"}}]}', 'model': 'qwen-3.6-27b', 'role': 'assistant'}), ('conversation', {'prompt': '/t create_artifact of type prompt it name should be Requirement and it content should be  "[LAB] Requirements"', 'response': '\n\n{"actions":[{"tool":"create_artifact","input":{"name":"Requirement","type":"prompt","content":"[LAB] Requirements"}}]}', 'model': 'qwen-3.6-27b', 'role': 'assistant'}), ('conversation', {'prompt': '/t build_capella_model_embeddings capella_model: {"type": "capella_model", "name": "EBSD_300" }', 'response': '\n\n{"actions":[{"tool":"build_capella_model_embeddings","input":{"capella_model":{"type":"capella_model","name":"EBSD_300"}}}]}', 'model': 'qwen-3.6-27b', 'role': 'assistant'}), ('conversation', {'prompt': '/t query_capella_embeddings EBSD_300_emb with prompt artifact name ="Requirements" return to 1', 'response': '\n\n{"actions":[{"tool":"query_capella_embeddings","input":{"embeddings":{"type":"embeddings","name":"EBSD_300_emb"},"prompt":{"type":"prompt","name":"Requirement"},"top_n":1}}]}', 'model': 'qwen-3.6-27b', 'role': 'assistant'}), ('conversation', {'prompt': '/t table column to list  colume: uuid name the list EBSD_300_uuids', 'response': '\n\n{"actions":[{"tool":"table_column_to_list","input":{"table":{"type":"table"},"column":"uuid","name":"EBSD_300_uuids"}}]}', 'model': 'qwen-3.6-27b', 'role': 'assistant'}), ('conversation', {'prompt': '/t generate_arcadia_fabric capella_model: {"type": "capella_model", "name": "EBSD_300" }, targets_list: {"type": "list", "name": "EBSD_300_uuids"}', 'response': '\n\n{"actions":[{"tool":"generate_arcadia_fabric","input":{"capella_model":{"type":"capella_model","name":"EBSD_300"},"targets_list":{"type":"list","name":"EBSD_300_uuids"}}}]}', 'model': 'qwen-3.6-27b', 'role': 'assistant'}), ('conversation', {'prompt': '/t load_prompt_def_artifact prompt_title: "Capella_Requirement" prompt_dir_ref: prompt_dir_path', 'response': '\n\n{"actions":[{"tool":"load_prompt_def_artifact","input":{"prompt_title":"Capella_Requirement","prompt_dir_ref":{"type":"prompt_path","name":"prompt_dir_path"}}}]}', 'model': 'qwen-3.6-27b', 'role': 'assistant'}), ('conversation', {'prompt': '/t render_prompt_artifact {"prompt_def": {"type":"prompt_def", "name":"Capella_Requirement"}, output_name: "Capella_Requirment_Rend" }', 'response': '\n\n{"actions":[{"tool":"render_prompt_artifact","input":{"prompt_def":{"type":"prompt_def","name":"Capella_Requirement"},"output_name":"Capella_Requirment_Rend"}}]}', 'model': 'qwen-3.6-27b', 'role': 'assistant'}), ('conversation', {'prompt': '/t reason_on_arcadia_fabric_or_files using arcadia_fabric_fab and prompt Capella_Requirment_Rend', 'response': '\n\n{"actions":[{"tool":"reason_on_arcadia_fabric_or_files","input":{"arcadia_fabric_name":"arcadia_fabric_fab","prompt_name":"Capella_Requirment_Rend"}}]}', 'model': 'qwen-3.6-27b', 'role': 'assistant'}), ('conversation', {'prompt': '/t write_csv of the table from the message response name it EBSD_Requirements', 'response': '\n\n{"actions":[{"tool":"write_csv","input":{"filename":"EBSD_Requirements.csv","data":[{"Prefix":"REQ-000062/A","Name":"Provide Storage Capabilities","Long Name":"Provide Storage Capabilities","Text":"The EBSD system shall provide mass storage for programs and data. It should be able to transfer data to and from mass storage devices, subject only to size limitations.","Relations":"Satisfy","Relation Target":"EBSD"},{"Prefix":"REQ-000057/A","Name":"Provide Execution Capabilities","Long Name":"Provide Execution Capabilities","Text":"EBSD PC shall be Specific user\'s EBSD PC hardware/software system configuration execution capability requirements the responsibility of the user. ...
# input data: {'filename': 'replay.ipynb'}
# resolved input: {'filename': 'replay.ipynb'}
# JIT Input: {'filename': 'replay.ipynb'}

# %%
result = agent.run(
    "notebook_export",
    input_data={
        "export_html": True,
        "source_ipynb": r"/home/simcenter/studio/knowledge_partner/EBSD_Requirements_Analysis.ipynb",
    },
    agent=agent
)
# Out:
# input data: {'export_html': True, 'source_ipynb': '/home/simcenter/studio/knowledge_partner/EBSD_Requirements_Analysis.ipynb'}
# resolved input: {'export_html': True, 'source_ipynb': '/home/simcenter/studio/knowledge_partner/EBSD_Requirements_Analysis.ipynb'}
# JIT Input: {'export_html': True, 'source_ipynb': '/home/simcenter/studio/knowledge_partner/EBSD_Requirements_Analysis.ipynb'}
