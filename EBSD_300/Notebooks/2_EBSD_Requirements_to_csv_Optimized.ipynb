# %% [markdown]
# # Generative AI Enabled Simcenter Studio Notebook
# ## Requirements extraction from Model
#
# Requirements are extracted from the system model diagram "Logical Architecture Diagram  [LAB] Requirements"" and captured in a file named "EBSD_Requirements.csv".
# The extraction and formatting of report is done by predefined prompt.

# %%
from se_agent.core.agent import AgentCore

#agent = AgentCore(debug=True)
agent = AgentCore()
agent.create_package("SE_Solutions")
agent.use_package("SE_Solutions")
# Out:
# /usr/local/lib/python3.12/dist-packages/langgraph/checkpoint/serde/encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer
# 🧩 Registered tool: build_capella_model_embeddings – BUILD AND REGISTER EMBEDDINGS FOR A CAPELLA MODEL. (modes=('DEFAULT',))
# 🧩 Registered tool: create_artifact – Create a new artifact with the given name, type, and content in the target package. (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: create_capella_model_artifact – CREATE A SINGLE CAPELLA_MODEL ARTIFACT FROM PATH AND RESOURCES. (modes=('DEFAULT',))
# ⚠️ Tool 'create_file_reference' did not declare APPLICABLE_MODES; defaulting to ('DEFAULT',).
# ...

# %% [markdown]
# ### Step 1: Run `create_capella_model_artifact`
# Package: `SE_Solutions`
# Input: `{'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird', 'name': 'EBSD_300', 'resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}}`

# %%
#agent.act("/t create_capella_model_artifact','path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird','name': 'EBSD_300','resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}}")
_ = agent.run('create_capella_model_artifact', package_name='SE_Solutions', input_data={'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird', 'name': 'EBSD_300', 'resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}}, **{})
# Out:
# input data: {'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird', 'name': 'EBSD_300', 'resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}}
# ✅ Artifact created: name='_workspace_store' id='b26312ce' type='workspace' in package 'SE_Solutions'
# resolved input: {'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird', 'name': 'EBSD_300', 'resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}}
# JIT Input: {'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird', 'name': 'EBSD_300', 'resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}}
# ✅ Artifact created: name='EBSD_300' id='a44271eb' type='capella_model' in package 'SE_Solutions'

# %% [markdown]
# ### Step 2: Run `load_prompt_path`
# Package: `SE_Solutions`
# Input: `{'prompt_dir_path': '/home/simcenter/studio/EBSD_300/EBSD_300/Notebooks/prompt_library', 'name': 'prompt_dir_path'}`

# %%
#res = agent.act('/t load_prompt_path prompt_dir_path :  "/home/simcenter/studio/EBSD_300/EBSD_300/Notebooks/prompt_library" , Name:  "prompt_dir_path" ')
##from pprint import pprint; pprint(res)
_ = agent.run('load_prompt_path', package_name='SE_Solutions', input_data={'prompt_dir_path': '/home/simcenter/studio/EBSD_300/EBSD_300/Notebooks/prompt_library', 'name': 'prompt_dir_path'}, **{})
# Out:
# input data: {'prompt_dir_path': '/home/simcenter/studio/EBSD_300/EBSD_300/Notebooks/prompt_library', 'name': 'prompt_dir_path'}
# resolved input: {'prompt_dir_path': '/home/simcenter/studio/EBSD_300/EBSD_300/Notebooks/prompt_library', 'name': 'prompt_dir_path'}
# JIT Input: {'prompt_dir_path': '/home/simcenter/studio/EBSD_300/EBSD_300/Notebooks/prompt_library', 'name': 'prompt_dir_path'}
# ✅ Artifact created: name='prompt_dir_path' id='4632068c' type='prompt_path' in package 'SE_Solutions'

# %% [markdown]
# ### Step 3: Run `create_artifact`
# Package: `SE_Solutions`
# Input: `{'name': 'Requirement', 'type': 'prompt', 'content': '[LAB] Requirements'}`

# %%
#res = agent.act('/t create_artifact of type prompt it name should be Requirement and it content should be  "[LAB] Requirements"')
##from pprint import pprint; pprint(res)
_ = agent.run('create_artifact', package_name='SE_Solutions', input_data={'name': 'Requirement', 'type': 'prompt', 'content': '[LAB] Requirements'}, **{})
# Out:
# input data: {'name': 'Requirement', 'type': 'prompt', 'content': '[LAB] Requirements'}
# resolved input: {'name': 'Requirement', 'type': 'prompt', 'content': '[LAB] Requirements'}
# JIT Input: {'name': 'Requirement', 'type': 'prompt', 'content': '[LAB] Requirements'}
# ✅ Artifact created: name='Requirement' id='63bec0b7' type='prompt' in package 'SE_Solutions'
# [remember] create_artifact: declared remember for ['artifact_id'] but no artifact_ids returned.

# %% [markdown]
# ### Step 4: Run `build_capella_model_embeddings`
# Package: `SE_Solutions`
# Input: `{'capella_model': {'type': 'capella_model', 'name': 'EBSD_300'}}`

# %%
#res = agent.act('/t build_capella_model_embeddings capella_model: {"type": "capella_model", "name": "EBSD_300" }')
##from pprint import pprint; pprint(res)
_ = agent.run('build_capella_model_embeddings', package_name='SE_Solutions', input_data={'capella_model': {'type': 'capella_model', 'name': 'EBSD_300'}}, **{})
# Out:
# input data: {'capella_model': {'type': 'capella_model', 'name': 'EBSD_300'}}
# resolved input: {'capella_model': {'type': 'capella_model', 'name': 'EBSD_300'}}
# JIT Input: {'capella_model': {'artifact_id': 'a44271eb-77f9-4708-832c-137e431aeac7'}}
# ✅ EmbeddingManager initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: text-embedding-3-small
# Loading embeddings
# embeddings loaded.
# ✅ Artifact created: name='EBSD_300_emb' id='306224fa' type='embeddings' in package 'SE_Solutions'

# %% [markdown]
# ### Step 5: Run `query_capella_embeddings`
# Package: `SE_Solutions`
# Input: `{'embeddings': {'type': 'embeddings', 'name': 'EBSD_300_emb'}, 'prompt': {'type': 'prompt', 'name': 'Requirements'}, 'top_n': 1}`

# %%
#
#res = agent.act('/t query_capella_embeddings embeddings: EBSD_300_emb with prompt artifact name ="Requirements" return to 1 ')
##from pprint import pprint; pprint(res)
_ = agent.run('query_capella_embeddings', package_name='SE_Solutions', input_data={'embeddings': {'type': 'embeddings', 'name': 'EBSD_300_emb'}, 'prompt': {'type': 'prompt', 'name': 'Requirements'}, 'top_n': 1}, **{})
# Out:
# input data: {'embeddings': {'type': 'embeddings', 'name': 'EBSD_300_emb'}, 'prompt': {'type': 'prompt', 'name': 'Requirements'}, 'top_n': 1}
# resolved input: {'embeddings': {'type': 'embeddings', 'name': 'EBSD_300_emb'}, 'prompt': {'type': 'prompt', 'name': 'Requirements'}, 'top_n': 1}
# JIT Input: {'embeddings': {'artifact_id': '306224fa-1305-4fd2-918f-fe537eaaf691'}, 'prompt': {'artifact_id': '63bec0b7-7c1b-429f-acd0-e50b15ea6687'}, 'top_n': 1}
# ✅ EmbeddingManager initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: text-embedding-3-small
# Loading embeddings
# embeddings loaded.
# ✅ Embedding created in 0.42s [query=[LAB] Requirements]
#
# This is a list of ranked Objects Based on Query:
# Index: 0, Name: [LAB] Requirements, Similarity: 0.62, Type: DRepresentationDescriptor, Phase: Logical Architecture LA, Source: , Target:
# ✅ Artifact created: name='EBSD_300_emb_query_results' id='9ead1671' type='table' in package 'SE_Solutions'

# %% [markdown]
# ### Step 6: Run `table_column_to_list`
# Package: `SE_Solutions`
# Input: `{'table': {'type': 'table', 'name': 'EBSD_300_emb_query_results'}, 'column': 'uuid', 'name': 'EBSD_300_uuids'}`

# %%
#res = agent.act("/t table_column_to_list column:uuid  name the list EBSD_300_uuids")
##from pprint import pprint; pprint(res)
##Start interactive chat with file attach + artifact capture
## Call chat as a tool
##agent.run("interactive_chat", input_data={
##    "context": "You are a systems engineering assistant."
##}, agent=agent)
_ = agent.run('table_column_to_list', package_name='SE_Solutions', input_data={'table': {'type': 'table', 'name': 'EBSD_300_emb_query_results'}, 'column': 'uuid', 'name': 'EBSD_300_uuids'}, **{})
# Out:
# input data: {'table': {'type': 'table', 'name': 'EBSD_300_emb_query_results'}, 'column': 'uuid', 'name': 'EBSD_300_uuids'}
# resolved input: {'table': {'type': 'table', 'name': 'EBSD_300_emb_query_results'}, 'column': 'uuid', 'name': 'EBSD_300_uuids'}
# JIT Input: {'table': {'artifact_id': '9ead1671-088c-42f6-9b32-24212432f60f'}, 'column': 'uuid', 'name': 'EBSD_300_uuids'}
# ✅ Artifact created: name='EBSD_300_uuids' id='388636ad' type='list' in package 'SE_Solutions'

# %% [markdown]
# ### Step 7: Run `generate_arcadia_fabric`
# Package: `SE_Solutions`
# Input: `{'capella_model': {'type': 'capella_model', 'name': 'EBSD_300'}, 'targets_list': {'type': 'list', 'name': 'EBSD_300_uuids'}}`

# %%
#res = agent.act('/t generate_arcadia_fabric capella_model: {"type": "capella_model", "name": "EBSD_300" }, targets_list: {"type": "list", "name": "EBSD_300_uuids"}')
##from pprint import pprint; pprint(res)
_ = agent.run('generate_arcadia_fabric', package_name='SE_Solutions', input_data={'capella_model': {'type': 'capella_model', 'name': 'EBSD_300'}, 'targets_list': {'type': 'list', 'name': 'EBSD_300_uuids'}}, **{})
# Out:
# input data: {'capella_model': {'type': 'capella_model', 'name': 'EBSD_300'}, 'targets_list': {'type': 'list', 'name': 'EBSD_300_uuids'}}
# resolved input: {'capella_model': {'type': 'capella_model', 'name': 'EBSD_300'}, 'targets_list': {'type': 'list', 'name': 'EBSD_300_uuids'}}
# JIT Input: {'capella_model': {'artifact_id': 'a44271eb-77f9-4708-832c-137e431aeac7'}, 'targets_list': {'artifact_id': '388636ad-aa96-4282-bf70-72c90d4d8b99'}}
# /usr/local/lib/python3.12/dist-packages/jinja2/environment.py:490: FutureWarning: CapellaOutgoingRelation cannot have a '.name', please update your code to check if the field exists or if the object subclasses modellingcore.AbstractNamedElement
#   return getattr(obj, attribute)
# /usr/local/lib/python3.12/dist-packages/capella_tools/capellambse_yaml_manager.py:3016: FutureWarning: CapellaOutgoingRelation cannot have a '.name', please update your code to check if the field exists or if the object subclasses modellingcore.AbstractNamedElement
# ...

# %% [markdown]
# ### Step 8: Run `load_prompt_def_artifact`
# Package: `SE_Solutions`
# Input: `{'prompt_title': 'Capella_Requirement', 'prompt_dir_ref': {'type': 'prompt_path', 'name': 'prompt_dir_path'}}`

# %%
#res = agent.act('/t load_prompt_def_artifact prompt_title: "Capella_Requirement" prompt_dir_ref: prompt_dir_path' )
##from pprint import pprint; pprint(res)
_ = agent.run('load_prompt_def_artifact', package_name='SE_Solutions', input_data={'prompt_title': 'Capella_Requirement', 'prompt_dir_ref': {'type': 'prompt_path', 'name': 'prompt_dir_path'}}, **{})
# Out:
# input data: {'prompt_title': 'Capella_Requirement', 'prompt_dir_ref': {'type': 'prompt_path', 'name': 'prompt_dir_path'}}
# resolved input: {'prompt_title': 'Capella_Requirement', 'prompt_dir_ref': {'type': 'prompt_path', 'name': 'prompt_dir_path'}}
# JIT Input: {'prompt_title': 'Capella_Requirement', 'prompt_dir_ref': {'artifact_id': '4632068c-cf00-4ca6-bb22-ef4933df1325'}}
# ✅ Artifact created: name='Capella_Requirement' id='a01b8e8f' type='prompt_def' in package 'SE_Solutions'

# %% [markdown]
# ### Step 9: Run `render_prompt_artifact`
# Package: `SE_Solutions`
# Input: `{'prompt_def': {'type': 'prompt_def', 'name': 'Capella_Requirement'}, 'output_name': 'Capella_Requirment_Rend'}`

# %%
#res = agent.act('/t render_prompt_artifact {"prompt_def": {"type":"prompt_def", "name":"Capella_Requirement"}, output_name: "Capella_Requirment_Rend" }')
##from pprint import pprint; pprint(res)
_ = agent.run('render_prompt_artifact', package_name='SE_Solutions', input_data={'prompt_def': {'type': 'prompt_def', 'name': 'Capella_Requirement'}, 'output_name': 'Capella_Requirment_Rend'}, **{})
# Out:
# input data: {'prompt_def': {'type': 'prompt_def', 'name': 'Capella_Requirement'}, 'output_name': 'Capella_Requirment_Rend'}
# resolved input: {'prompt_def': {'type': 'prompt_def', 'name': 'Capella_Requirement'}, 'output_name': 'Capella_Requirment_Rend'}
# JIT Input: {'prompt_def': {'artifact_id': 'a01b8e8f-f6d9-4f7a-9162-65aefe961262'}, 'output_name': 'Capella_Requirment_Rend'}
# ✅ Artifact created: name='Capella_Requirment_Rend' id='f132730a' type='prompt' in package 'SE_Solutions'

# %% [markdown]
# ### Step 10: Run `reason_on_arcadia_fabric_or_files`
# Package: `SE_Solutions`
# Input: `{'arcadia_fabric_name': 'arcadia_fabric_fab', 'prompt_name': 'Capella_Requirment_Rend'}`

# %%
res = agent.act('/t reason_on_arcadia_fabric_or_files using arcadia_fabric_name: arcadia_fabric_fab, and prompt_name Capella_Requirment_Rend' )
##from pprint import pprint; pprint(res)
##res = agent.act('/t reason_and_publish_on_arcadia_fabric_files output_dir=./reports arcadia_fabric_name=arcadia_fabric_fab  prompt= Capella_Requirment_Rend')
#_ = agent.run('reason_on_arcadia_fabric_or_files', package_name='SE_Solutions', input_data={'arcadia_fabric_name': 'arcadia_fabric_fab', 'prompt_name': 'Capella_Requirment_Rend'}, **{})
# Out:
# ✅ Planned tool actions now executing:{"actions":[{"tool":"reason_on_arcadia_fabric_or_files","input":{"arcadia_fabric_name":"arcadia_fabric_fab","prompt_name":"Capella_Requirment_Rend"}}]}
# **Your prompt:** Please analyze the yaml file and display all Requirements for the diagram:
# 1. Format the requirement in a table.
# 2. Include its prefix, name, long_name, text, its relations and relation target. Format the response in .html format.
# Below is the HTML representation of the requirements extracted from the YAML file, formatted in a table:
#
# ```html
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Requirements Table</title>
#
# </head>
# <body>
# <table>
# <thead>
# <tr>
# <th>Prefix</th>
# <th>Name</th>
# <th>Long Name</th>
# <th>Text</th>
# <th>Relations</th>
# <th>Relation Target</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>REQ-000062/A</td>
# <td></td>
# ...

# %% [markdown]
# ### Step 11: Run `write_csv`
# Package: `SE_Solutions`
# Input: `{'filename': 'EBSD_Requirements.csv', 'from_last_message': True}`

# %%
res = agent.act('/t write_csv filename="EBSD_Requirements.csv" from_last_message=true')
##from pprint import pprint; pprint(res)
#_ = agent.run('write_csv', package_name='SE_Solutions', input_data={'filename': 'EBSD_Requirements.csv', 'from_last_message': True}, **{})
# Out:
# ✅ Planned tool actions now executing:{"actions":[{"tool":"write_csv","input":{"filename":"EBSD_Requirements.csv","from_last_message":true}}]}
# 📋 Wrote CSV to EBSD_Requirements.csv
