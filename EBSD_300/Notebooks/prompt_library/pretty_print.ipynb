# %% [markdown]
# # Prttry Print Prompt
#
# This notebook emits a JSON prompt spec via a code cell tagged `prompt_json`.

# %%
key = "pretty print"
title_name = "pretty print"
description = "Produce and Engineer friendly report."
version = "0.1.0"
template = """You are an MBSE assistant formation a report.
Generate a engineer friendly report from the json or yaml souce provide.
Constraints:
- Be precise and concise\n- Prefer enumerations/ids if available
"""

# %%
import json
from IPython.display import JSON

PROMPT = {
    "key": key,
    "title": title_name,
    "description": description,
    "version": version,
    "template": template,
    "variables": [],
    "tags": [
    "format",
    "pretty",
    "capella",
    "fabric"
    ]
    }

# Emit as structured JSON so the tool can capture it (cell is tagged 'prompt_json')
JSON(PROMPT)
