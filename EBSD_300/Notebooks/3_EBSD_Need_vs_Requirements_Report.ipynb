# %% [markdown]
# # Generative AI Enabled Simcenter Studio Notebook
# ## Needs to Requirements Report
#
# This notebook takes the EBSD_Needs.csv and uses Generative AI driven by prompt to compare it against the EBSD_Requirement.csv.  The result will be a table displayed as define by the prompt.

# %%
from se_agent.core.agent import AgentCore

#agent = AgentCore(debug=True)
agent = AgentCore()
agent.create_package("SE_Solutions")
agent.use_package("SE_Solutions")

#res = agent.run('load_prompt_path', input_data={'prompt_dir_path': '/home/simcenter/studio/knowledge_partner/prompt_library/' })
#from pprint import pprint; pprint(res)
agent.run('create_capella_model_artifact', input_data=
          {'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird',
           'name': 'EBSD_300',
           'resources': {"EBSD": "/home/simcenter/studio/EBSD_300/EBSD_300"}})
# Out:
# 🧩 Registered tool: build_capella_model_embeddings – BUILD AND REGISTER EMBEDDINGS FOR A CAPELLA MODEL. (modes=('DEFAULT',))
# 🧩 Registered tool: create_artifact – Create a new artifact with the given name, type, and content in the target package. (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: create_capella_model_artifact – CREATE A SINGLE CAPELLA_MODEL ARTIFACT FROM PATH AND RESOURCES. (modes=('DEFAULT',))
# ⚠️ Tool 'create_file_reference' did not declare APPLICABLE_MODES; defaulting to ('DEFAULT',).
# 🧩 Registered tool: create_file_reference – Create a 'file_reference' artifact for a local file (path + metadata only). (modes=('DEFAULT',))
# 🧩 Registered tool: create_folder_path – CREATE A FOLDER_PATH ARTIFACT FROM A DIRECTORY PATH (OPTIONALLY CREATE THE DIRECTORY). (modes=('DEFAULT',))
# 🧩 Registered tool: create_scaffold_artifact_for_tool – Create a blank spec artifact for a tool's artifact_ref input by inspecting the tool's IO_SCHEMA. (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: create_sysmlv2_snapshot_artifact – CREATE A SINGLE SYSML V2 SNAPSHOT ARTIFACT FROM REPO/PROJECT/COMMIT IDS. (modes=('DEFAULT',))
# 🧩 Registered tool: execute_diagram_retrieve – QUERY CAPELLA EMBEDDINGS, FIND SVG SNAPSHOT DIAGRAMS BY NAME, CREATE DIAGRAM ARTIFACTS, DISPLAY INLINE. (modes=('DEFAULT',))
# ⚠️ Tool 'execute_display_context_diagram' did not declare APPLICABLE_MODES; defaulting to ('DEFAULT',).
# 🧩 Registered tool: execute_display_context_diagram –  (modes=('DEFAULT',))
# 🧩 Registered tool: execute_fabric_publish – Publish a Markdown report generated directly from an arcadia_fabric YAML (and optional file_reference content) without vector-store retrieval. Mirrors execute_rag_publish publishing behaviors. (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: execute_prompt_for_session – Start a Creative/Freeform Session from an optional prompt artifact; optionally attach other artifacts (incl. file_artifact/file_reference) into Session Workspace Memory. (modes=('DEFAULT',))
# ⚠️ Tool 'execute_publish_context_diagram' did not declare APPLICABLE_MODES; defaulting to ('DEFAULT',).
# 🧩 Registered tool: execute_publish_context_diagram – Publish markdown and optional HTML/meta.json for Capella context diagrams for a list of UUIDs. Generates SVG files using obj.context_diagram.render('svgdiagram', mode=...). (modes=('DEFAULT',))
# 🧩 Registered tool: execute_publish_diagram_retrieve – QUERY EMBEDDINGS → FIND SVG SNAPSHOTS → COPY+PUBLISH MD/HTML/META (CSID bundle). (modes=('DEFAULT',))
# 🧩 Registered tool: execute_rag_analysis – Summarize/analyze one or more file_artifact documents using RAG over their OpenAI vector stores. Provide either 'summary_prompt' (string) or 'prompt' (prompt artifact ref). (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: execute_rag_publish – Publish a RAG-generated Markdown report to disk (optionally HTML + meta.json), using file_artifact sources indexed in vector stores. Captures provenance for CSID. (modes=('DEFAULT', 'SESSION'))
# ⚠️ Tool 'extract_word_tables_to_csv' did not declare APPLICABLE_MODES; defaulting to ('DEFAULT',).
# 🧩 Registered tool: extract_word_tables_to_csv – Extract tables from a Word .docx to multiple CSVs plus manifest.yaml; registers file_references. (modes=('DEFAULT',))
# 🧩 Registered tool: name_artifact – ASSIGN A NAME TO AN EXISTING ARTIFACT (LOOKUP BY ID OR LATEST OF TYPE). (modes=('DEFAULT',))
# 🧩 Registered tool: generate_arcadia_fabric – GENERATE ARCADIA YAML FABRIC FROM A CAPELLA MODEL AND A LIST OF UUIDS. (modes=('DEFAULT',))
# 🧩 Registered tool: generate_sysmlv2_fabric – GENERATES A SYSML V2 QUERY-BASED FABRIC, SAVES AS JSON, AND UPLOADS AS FILE ARTIFACT. (modes=('DEFAULT',))
# 🧩 Registered tool: interactive_chat – LAUNCHES AN INTERACTIVE CHAT SESSION; USES LLM_CHAT INTERNALLY. (modes=('DEFAULT',))
# 🧩 Registered tool: list_artifacts – List artifacts in the active (or specified) package with a Markdown summary. Optional filters: type, max_rows. (modes=('DEFAULT',))
# 🧩 Registered tool: list_workspace – DISPLAYS THE CURRENT WORKSPACE CONTENTS: ARTIFACTS AND MEMORY ENTRIES (with Markdown summary). (modes=('DEFAULT',))
# 🧩 Registered tool: llm_chat – CONDUCTS A TOOL-AWARE CHAT WITH THE LLM AND STORES CONVERSATION TURNS. (modes=('DEFAULT',))
# 🧩 Registered tool: load_artifact_into_workspace_memory – Load an artifact into workspace ⚙️ memory by ref/name or latest type; optional rename; returns one-shot injection. (modes=('DEFAULT',))
# 🧩 Registered tool: load_from_workspace_memory_to_artifact – LOAD A WORKSPACE MEMORY ENTRY AS A TYPED ARTIFACT (FOR TOOL USE). (modes=('DEFAULT',))
# 🧩 Registered tool: load_prompt_def_artifact – Load a prompt JSON from a directory (or prompt_path reference) and create an artifact of type 'prompt'. (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: load_prompt_path – LOADS A DIRECTORY OF NOTEBOOK-DEFINED PROMPTS AND SAVES A POINTER ARTIFACT FOR OTHER TOOLS TO USE. (modes=('DEFAULT',))
# 🧩 Registered tool: notebook_export – EXPORT AGENT HISTORY AS A REPLAY NOTEBOOK AND/OR EXPORT HTML SNAPSHOTS (WITH OPTIONAL CHAT TRANSCRIPT INJECTION). (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: query_capella_embeddings – QUERY A PRE-BUILT CAPELLA EMBEDDINGS ARTIFACT USING A PROMPT. (modes=('DEFAULT',))
# 🧩 Registered tool: read_csv – IMPORT A CSV AND CREATE A 'TABLE' ARTIFACT (COLUMNS + RECORDS). (modes=('DEFAULT',))
# 🧩 Registered tool: read_leveled_csv – IMPORTS A LEVELED CSV FILE AND CREATES A HIERARCHY ARTIFACT. (modes=('DEFAULT',))
# 🧩 Registered tool: read_workspace_memory – READS A SINGLE WORKSPACE MEMORY ITEM BY NAME AND RETURNS ITS STORED VALUE/METADATA. (modes=('DEFAULT',))
# 🧩 Registered tool: reason_and_publish_on_arcadia_fabric_files – Reason on an arcadia_fabric and/or file_reference artifacts using ChatGPTAnalyzer, then publish the result to disk (md + optional meta.json + optional html), modeled after execute_rag_publish. (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: reason_on_arcadia_fabric_or_files – Reason on an arcadia_fabric and/or file_reference artifacts using ChatGPTAnalyzer. (modes=('DEFAULT',))
# 🧩 Registered tool: render_prompt_artifact – Render a prompt_def using runtime variables and create a rendered prompt artifact. (modes=('DEFAULT', 'SESSION'))
# 🧩 Registered tool: save_prompt_def_artifact – Saves a rendered prompt definition as a prompt_def artifact and also persists a JSON prompt file to a prompt_path directory. (modes=('DEFAULT',))
# 🧩 Registered tool: search_prompts – LISTS PROMPTS WITHIN A PROMPT_PATH ARTIFACT, WITH OPTIONAL FILTERING. (modes=('DEFAULT',))
# 🧩 Registered tool: show_artifact – DISPLAY A STORED ARTIFACT (RAW CONTENT) BY ID, NAME, OR TYPE. (modes=('DEFAULT',))
# 🧩 Registered tool: show_artifact_memory – SUMMARIZE ARTIFACTS IN A PACKAGE WITH COUNTS AND EXAMPLES. Optional inputs: package_name (str), type_filter (str), max_names (int, default 8). (modes=('DEFAULT',))
# 🧩 Registered tool: show_prompt_spec – DISPLAYS A PROMPT_SPEC ARTIFACT WITH TITLE, VERSION, AND JSON PREVIEW. (modes=('DEFAULT',))
# 🧩 Registered tool: table_column_to_list – EXTRACT A COLUMN FROM A TABLE ARTIFACT AND CREATE A LIST ARTIFACT. (modes=('DEFAULT',))
# 🧩 Registered tool: upload_file_as_artifact – Upload a file and register it as a 'file_artifact' tied to an OpenAI vector store, then attach it to workspace memory. (modes=('DEFAULT',))
# 🧩 Registered tool: write_csv – Write a list of rows to a CSV file (source: input data or a 'table' artifact). (modes=('DEFAULT',))
# 🧩 Registered tool: write_leveled_csv – Write a hierarchical breakdown to CSV. Optionally add a column and persist updated hierarchy to artifacts. (modes=('DEFAULT',))
# [contract] Tool 'build_capella_model_embeddings' has remember-outputs ['embeddings_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'create_artifact' has remember-outputs ['artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'create_capella_model_artifact' has remember-outputs ['capella_model_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'create_folder_path' has remember-outputs ['folder_path_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'create_scaffold_artifact_for_tool' has remember-outputs ['artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'create_sysmlv2_snapshot_artifact' has remember-outputs ['sysmlv2_snapshot_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'execute_diagram_retrieve' has remember-outputs ['diagram_artifact_ids']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'execute_publish_diagram_retrieve' has remember-outputs ['diagram_artifact_ids']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'extract_word_tables_to_csv' has remember-outputs ['manifest_file_reference', 'csv_file_references']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'generate_sysmlv2_fabric' has remember-outputs ['file']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'llm_chat' has remember-outputs ['conversation_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'load_from_workspace_memory_to_artifact' has remember-outputs ['artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'load_prompt_path' has remember-outputs ['prompt_path_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'query_capella_embeddings' has remember-outputs ['table_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'read_csv' has remember-outputs ['table_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'read_leveled_csv' has remember-outputs ['hierarchy_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'read_workspace_memory' has remember-outputs ['name', 'type', 'origin_artifact_id', 'value']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'table_column_to_list' has remember-outputs ['list_artifact_id']. Ensure it returns result['artifact_ids'][name] on success.
# [contract] Tool 'upload_file_as_artifact' has remember-outputs ['file']. Ensure it returns result['artifact_ids'][name] on success.
# input data: {'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird', 'name': 'EBSD_300', 'resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}}
# ✅ Artifact created: name='_workspace_store' id='3efcdef1' type='workspace' in package 'SE_Solutions'
# resolved input: {'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird', 'name': 'EBSD_300', 'resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}}
# JIT Input: {'path_to_model': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird', 'name': 'EBSD_300', 'resources': {'EBSD': '/home/simcenter/studio/EBSD_300/EBSD_300'}}
# ✅ Artifact created: name='EBSD_300' id='1321e255' type='capella_model' in package 'SE_Solutions'
# {'message': "✅ Created capella_model artifact 📋 from '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird'.",
#  'artifact_ids': {'capella_model_artifact_id': '1321e255-91f3-493e-a3a3-4f4a6980a841'},
#  'path': '/home/simcenter/studio/EBSD_300/EBSD_300/EBSD_300.aird',
#  'named': True,
#  'artifact_message': "✅ Artifact created: name='_workspace_store' id='3efcdef1' type='workspace' in package 'SE_Solutions'"}

# %%
#Start interactive chat with file attach + artifact capture
# Call chat as a tool
#agent.run("interactive_chat", input_data={    "context": "You are a systems engineering assistant."}, agent=agent)

# %%
res = agent.act('/t load_prompt_path prompt_dir_path :  "/home/simcenter/studio/EBSD_300/EBSD_300/Notebooks/prompt_library" , Name:  "prompt_dir_path" ')
#from pprint import pprint; pprint(res)
# Out:
# ✅ Planned tool actions now executing:
#
# {"actions":[{"tool":"load_prompt_path","input":{"prompt_dir_path":"/home/simcenter/studio/knowledge_partner/prompt_library/","name":"prompt_dir_path"}}]}
# ✅ Prompt path loaded as artifact📋: id='09e5805b' (2 notebooks)

# %%
res = agent.act('/t load_prompt_def_artifact prompt_title: ""Need_to_Requirement_Impact" prompt_dir_ref: prompt_dir_path' )
#from pprint import pprint; pprint(res)
# Out:
# ✅ Planned tool actions now executing:
#
# {"actions":[{"tool":"load_prompt_def_artifact","input":{"prompt_dir_ref":{"type":"prompt_path","name":"prompt_dir_path"},"prompt_title":"Need_to_Requirement_Impact"}}]}
# ✅ Prompt_def 'Need_to_Requirement_Impact' created in package 'SE_Solutions'.

# %%
nt_file = "EBSD_Needs.csv"
rt_file = "EBSD_Requirements.csv"

action = '/t create_file_reference name:' +  nt_file + ' file_path: '+ nt_file
res = agent.act(action)

action = '/t create_file_reference name:' +  rt_file+ ' file_path: '+ rt_file
res = agent.act(action)

action= '/t render_prompt_artifact prompt_def: "Need_to_Requirement_Impact"  output_name :"Need_to_Requirement_Impact_rend" vars:{"NT": "' + nt_file + '", "RT":"' + rt_file + '"}' 
#print(action) 
res = agent.act(action)  
#from pprint import pprint; pprint(res)
action= '/t reason_on_arcadia_fabric_or_files using prompt artifact: "Need_to_Requirement_Impact_rend" file_reference: "' + rt_file + '", "' + nt_file+ '"'
#print(action) 
res = agent.act(action ) 
#from pprint import pprint; pprint(res)
#action= '/t write_csv of the table in last response, name it based on the names of source files: "Reqs_' +   nt_file+  '"'  
#res = agent.act(action )
#from pprint import pprint; pprint(res)
# Out:
# ✅ Planned tool actions now executing:
#
# {"actions":[{"tool":"create_file_reference","input":{"file_path":"EBSD_Needs.csv","name":"EBSD_Needs.csv"}}]}
# 📎 Registered 'EBSD_Needs.csv' as file_reference 'EBSD_Needs.csv'.
# ✅ Planned tool actions now executing:
#
# {"actions":[{"tool":"create_file_reference","input":{"file_path":"EBSD_Requirements.csv","name":"EBSD_Requirements.csv"}}]}
# 📎 Registered 'EBSD_Requirements.csv' as file_reference 'EBSD_Requirements.csv'.
# ✅ Planned tool actions now executing:
#
# {"actions":[{"tool":"render_prompt_artifact","input":{"prompt_def":{"type":"prompt_def","name":"Need_to_Requirement_Impact"},"output_name":"Need_to_Requirement_Impact_rend","vars":{"NT":"EBSD_Needs.csv","RT":"EBSD_Requirements.csv"}}}]}
# ✅ Planned tool actions now executing:
#
# {"actions":[{"tool":"reason_on_arcadia_fabric_or_files","input":{"prompt_name":"Need_to_Requirement_Impact_rend","file_reference_names":["EBSD_Requirements.csv","EBSD_Needs.csv"]}}]}
# **Your prompt:** Context: You are acting as a System Engineer tasked with assessing how a set of stated Needs may impact an existing set of system Requirements.
#
# Use the loaded requirements file named EBSD_Requirements.csv, which contains the existing Requirements data, and compare it against the provided Needs table EBSD_Needs.csv.
#
#
# Your goal is to identify requirements that:
# 1. may be directly impacted by a Need,
# 2. may be indirectly impacted by satisfying a Need,
# 3. may constrain delivery of the Need,
# 4. may need reconsideration because a performance-driven Need could increase power demand, thermal load, processing load, sensing rate, communication activity, or duty cycle.
#
# Instructions:
#
# Analyze each Need against the Requirements using a reasoning-only approach. Do not generate code.
#
# For each Need, compare its meaning against the Requirement fields, especially "Text" and "Long Name". Do not rely only on exact word matches. Also reason using engineering relationships and likely system behavior.
#
# When assessing impact, look for both direct and indirect connections such as:
# - performance increases that may drive higher power consumption,
# - faster response or update rates that may increase processor utilization,
# - improved accuracy or detection capability that may require more sensing, computation, or communication,
# - continuous or more frequent operation that may increase average or peak power,
# - increased power that may affect battery life, thermal limits, power supply sizing, or operating duration,
# - requirements that set limits on energy use, temperature, runtime, or resource usage and therefore may constrain the Need.
#
# Be inclusive in identifying potentially impacted requirements. Prefer capturing plausible engineering impacts rather than only obvious text similarity. If the relationship is indirect but credible, include it and explain the chain of reasoning.
#
# For each identified result, provide:
# - Req ID: the unique identifier of the Need
# - Need Long Name: a short title summarizing the Need
# - Need Description: the detailed Need text
# - Impacted Requirement ID: the unique ID of the Requirement that may be impacted or may constrain the Need
# - Requirement Long Name: the Long Name from the Requirement row
# - Requirement Text: the Text from the Requirement row
# - Impact Type: one of [Direct Impact, Indirect Impact, Constraint]
# - Rationale: a concise but specific explanation of why the Requirement is related, including performance-to-power reasoning where applicable
#
# Important guidance:
# - Explicitly look for cases where a performance need could impact power-related requirements even if the Need never uses the word "power".
# - Treat timing, speed, throughput, accuracy, refresh rate, resolution, communication frequency, startup time, and continuous monitoring as possible drivers of power impact.
# - Include multiple impacted requirements for a single Need when appropriate.
# - Do not omit a requirement simply because the relationship is indirect.
# - Do not invent requirement IDs or content not present in the loaded files.
#
# Output format:
# Present the results only as a single HTML table.
# Use these columns in this order:
# Req ID | Need Long Name | Need Description | Impacted Requirement ID | Requirement Long Name | Requirement Text | Impact Type | Rationale
#
# Return only valid HTML with no extra commentary. Format the response in .html format.
# <table>
# <thead>
# <tr>
# <th>Req ID</th>
# <th>Need Long Name</th>
# <th>Need Description</th>
# <th>Impacted Requirement ID</th>
# <th>Requirement Long Name</th>
# <th>Requirement Text</th>
# <th>Impact Type</th>
# <th>Rationale</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>REQ-000149/A</td>
# <td>Baseline Test Performance</td>
# <td>The EBSD system baseline test performance time needs to be reduced from 100 seconds to 66 seconds.</td>
# <td>REQ-000156/A</td>
# <td>Baseline Test Performance</td>
# <td>The EBSD System shall perform baseline performance test in 90 seconds.</td>
# <td>Direct Impact</td>
# <td>Reducing the baseline test time to 66 seconds directly modifies the existing 90-second performance requirement.</td>
# </tr>
# <tr>
# <td>REQ-000149/A</td>
# <td>Baseline Test Performance</td>
# <td>The EBSD system baseline test performance time needs to be reduced from 100 seconds to 66 seconds.</td>
# <td>REQ-000066/A</td>
# <td>Power</td>
# <td>Maximum power consumption shall be 430 W</td>
# <td>Indirect Impact</td>
# <td>Faster test execution typically requires higher CPU/GPU clock speeds or increased parallel processing, which raises peak power draw and must remain within the 430 W limit.</td>
# </tr>
# <tr>
# <td>REQ-000149/A</td>
# <td>Baseline Test Performance</td>
# <td>The EBSD system baseline test performance time needs to be reduced from 100 seconds to 66 seconds.</td>
# <td>REQ-000076/A</td>
# <td>Fanless CPU Cooling</td>
# <td>The EBSD System shall have heat-sink with no fans on CPU</td>
# <td>Constraint</td>
# <td>Passive cooling limits heat dissipation capacity. Higher computational loads for accelerated tests generate more heat, potentially exceeding thermal limits without active cooling.</td>
# </tr>
# <tr>
# <td>REQ-000149/A</td>
# <td>Baseline Test Performance</td>
# <td>The EBSD system baseline test performance time needs to be reduced from 100 seconds to 66 seconds.</td>
# <td>REQ-000163/A</td>
# <td>EBSD junction operating temperatures</td>
# <td>The operating temperature on boards shall not exceed 70° C.</td>
# <td>Indirect Impact</td>
# <td>Increased processing frequency and duty cycle during faster tests raise junction temperatures, requiring verification that they remain ≤70°C under peak load.</td>
# </tr>
# <tr>
# <td>REQ-000149/A</td>
# <td>Baseline Test Performance</td>
# <td>The EBSD system baseline test performance time needs to be reduced from 100 seconds to 66 seconds.</td>
# <td>REQ-000050/A</td>
# <td>Operating Thermal Environment</td>
# <td>EBSD System shall operate between 0 and 50 °C</td>
# <td>Indirect Impact</td>
# <td>Higher internal heat generation from accelerated processing may raise chassis temperatures, challenging the 0–50°C operating envelope in warm ambient conditions.</td>
# </tr>
# <tr>
# <td>REQ-000149/A</td>
# <td>Baseline Test Performance</td>
# <td>The EBSD system baseline test performance time needs to be reduced from 100 seconds to 66 seconds.</td>
# <td>REQ-000146/A</td>
# <td>Stability</td>
# <td>The Power Subsystem shall manage load distribution for system stability.</td>
# <td>Indirect Impact</td>
# <td>Rapid transitions between idle and high-performance states during faster tests create power transients, requiring robust load management to maintain system stability.</td>
# </tr>
# <tr>
# <td>REQ-000150/A</td>
# <td>USB-C Support</td>
# <td>The EBSD system needs to support USB-C to increase performance of data exchange and communication with devices under test.</td>
# <td>REQ-000152/A</td>
# <td>USB - A</td>
# <td>The EBSD System shall have two USB A ports.</td>
# <td>Direct Impact</td>
# <td>Adding USB-C support directly impacts the existing USB-A port requirement, potentially replacing, supplementing, or redefining the interface allocation.</td>
# </tr>
# <tr>
# <td>REQ-000150/A</td>
# <td>USB-C Support</td>
# <td>The EBSD system needs to support USB-C to increase performance of data exchange and communication with devices under test.</td>
# <td>REQ-000159/A</td>
# <td>USB Connector (V2.0)</td>
# <td>EBSD System shall have USB 2.0 Connector on the Front Panel for mass storage of data.</td>
# <td>Direct Impact</td>
# <td>Front panel USB 2.0 connector requirement will likely be updated to USB-C to support higher performance data exchange as specified in the Need.</td>
# </tr>
# <tr>
# <td>REQ-000150/A</td>
# <td>USB-C Support</td>
# <td>The EBSD system needs to support USB-C to increase performance of data exchange and communication with devices under test.</td>
# <td>REQ-000064/A</td>
# <td>Provide File Transfer Capabilities</td>
# <td>EBSD System shall be specific user's EBSD PC hardware/software system configuration requirements to transfer files are the responsibility of the user. The Simcenter EBSD PC support the transfer of files using the following USB connector (V2.0), LAN, Wireless</td>
# <td>Direct Impact</td>
# <td>File transfer capabilities currently specify USB 2.0; USB-C support updates the interface standard and throughput expectations for data transfer.</td>
# </tr>
# <tr>
# <td>REQ-000150/A</td>
# <td>USB-C Support</td>
# <td>The EBSD system needs to support USB-C to increase performance of data exchange and communication with devices under test.</td>
# <td>REQ-000054/A</td>
# <td>Provide Communication Capabilities</td>
# <td>EBSD System shall capture specific user's hardware/software system configuration requirements to transfer files are out of scope of this PTRS. The EBSD PC support the transfer of data for communication with the following interfaces: USB connector (V2.0),</td>
# <td>Direct Impact</td>
# <td>Communication capabilities currently specify USB 2.0; USB-C updates the interface for higher-speed device communication.</td>
# </tr>
# <tr>
# <td>REQ-000150/A</td>
# <td>USB-C Support</td>
# <td>The EBSD system needs to support USB-C to increase performance of data exchange and communication with devices under test.</td>
# <td>REQ-000066/A</td>
# <td>Power</td>
# <td>Maximum power consumption shall be 430 W</td>
# <td>Indirect Impact</td>
# <td>High-speed USB-C controllers, PHYs, and associated signal integrity circuitry consume more power than legacy USB 2.0, increasing overall system power draw.</td>
# </tr>
# <tr>
# <td>REQ-000150/A</td>
# <td>USB-C Support</td>
# <td>The EBSD system needs to support USB-C to increase performance of data exchange and communication with devices under test.</td>
# <td>REQ-000067/A</td>
# <td>Rear Panel Connections</td>
# <td>Rear Panel Connections shall beat the back of the box.</td>
# <td>Constraint</td>
# <td>Rear panel connection layout must accommodate the new USB-C port(s) while maintaining existing interface placements and mechanical constraints.</td>
# </tr>
# <tr>
# <td>REQ-000150/A</td>
# <td>USB-C Support</td>
# <td>The EBSD system needs to support USB-C to increase performance of data exchange and communication with devices under test.</td>
# <td>REQ-000061/A</td>
# <td>Usability</td>
# <td>All interfaces and control elements shall be on one side; easy accessibility / usability to interfaces and control elements in standard mounting.</td>
# <td>Constraint</td>
# <td>Usability requirement mandates all interfaces on one side; adding USB-C must comply with this physical arrangement and accessibility standards.</td>
# </tr>
# <tr>
# <td>REQ-000150/A</td>
# <td>USB-C Support</td>
# <td>The EBSD system needs to support USB-C to increase performance of data exchange and communication with devices under test.</td>
# <td>REQ-000163/A</td>
# <td>EBSD junction operating temperatures</td>
# <td>The operating temperature on boards shall not exceed 70° C.</td>
# <td>Indirect Impact</td>
# <td>Faster data rates through USB-C increase I/O controller activity and switching losses, generating additional heat that may affect board/junction temperatures.</td>
# </tr>
# <tr>
# <td>REQ-000168/A</td>
# <td>Reduce Product Cost</td>
# <td>The EBSD system product cost needs to be reduced by 10%.</td>
# <td>REQ-000165/A</td>
# <td>Component Costs</td>
# <td>The EBSD component cost shall not exceed 1500 USD.</td>
# <td>Direct Impact</td>
# <td>A 10% product cost reduction directly targets and modifies the component cost ceiling of 1500 USD.</td>
# </tr>
# <tr>
# <td>REQ-000168/A</td>
# <td>Reduce Product Cost</td>
# <td>The EBSD system product cost needs to be reduc
# **Token Usage Info:**
#
# Tokens used: prompt=3113, completion=8421, total=11534

# %%
#res = agent.act('Create a table from the requiremCreate ents that would be impacted by a change request of 30% improvement in performance, and a change to USB-C. Create a table that includes the requrement prefix,its long name, its text, and the rationale on the selection.')
#from pprint import pprint; pprint(res)

# %%
#res = agent.act('/t write_csv of the table')
#from pprint import pprint; pprint(res)

# %%
#Start interactive chat with file attach + artifact capture
#Call chat as a tool
#agent.run("interactive_chat", input_data={
#    "context": "You are a systems engineering assistant."
#}, agent=agent)

# %%
pkg = agent.artifacts.get_active_package()
print([ (a.type, a.content) for a in pkg.artifacts.values() if a.type == "conversation"])

#agent.dump_chat_transcript("Run Transcript")

result = agent.run("notebook_export", input_data={"filename": "replay.ipynb"}, agent=agent)
# Out:
# [('conversation', {'prompt': '/t load_prompt_path prompt_dir_path : "/home/simcenter/studio/knowledge_partner/prompt_library/" , Name:  "prompt_dir_path"', 'response': '\n\n{"actions":[{"tool":"load_prompt_path","input":{"prompt_dir_path":"/home/simcenter/studio/knowledge_partner/prompt_library/","name":"prompt_dir_path"}}]}', 'model': 'qwen-3.6-27b', 'role': 'assistant'}), ('conversation', {'prompt': '/t load_prompt_def_artifact prompt_title: ""Need_to_Requirement_Impact" prompt_dir_ref: prompt_dir_path', 'response': '\n\n{"actions":[{"tool":"load_prompt_def_artifact","input":{"prompt_dir_ref":{"type":"prompt_path","name":"prompt_dir_path"},"prompt_title":"Need_to_Requirement_Impact"}}]}', 'model': 'qwen-3.6-27b', 'role': 'assistant'}), ('conversation', {'prompt': '/t create_file_reference name:EBSD_Needs.csv file_path: EBSD_Needs.csv', 'response': '\n\n{"actions":[{"tool":"create_file_reference","input":{"file_path":"EBSD_Needs.csv","name":"EBSD_Needs.csv"}}]}', 'model': 'qwen-3.6-27b', 'role': 'assistant'}), ('conversation', {'prompt': '/t create_file_reference name:EBSD_Requirements.csv file_path: EBSD_Requirements.csv', 'response': '\n\n{"actions":[{"tool":"create_file_reference","input":{"file_path":"EBSD_Requirements.csv","name":"EBSD_Requirements.csv"}}]}', 'model': 'qwen-3.6-27b', 'role': 'assistant'}), ('conversation', {'prompt': '/t render_prompt_artifact prompt_def: "Need_to_Requirement_Impact"  output_name :"Need_to_Requirement_Impact_rend" vars:{"NT": "EBSD_Needs.csv", "RT":"EBSD_Requirements.csv"}', 'response': '\n\n{"actions":[{"tool":"render_prompt_artifact","input":{"prompt_def":{"type":"prompt_def","name":"Need_to_Requirement_Impact"},"output_name":"Need_to_Requirement_Impact_rend","vars":{"NT":"EBSD_Needs.csv","RT":"EBSD_Requirements.csv"}}}]}', 'model': 'qwen-3.6-27b', 'role': 'assistant'}), ('conversation', {'prompt': '/t reason_on_arcadia_fabric_or_files using prompt artifact: "Need_to_Requirement_Impact_rend" file_reference: "EBSD_Requirements.csv", "EBSD_Needs.csv"', 'response': '\n\n{"actions":[{"tool":"reason_on_arcadia_fabric_or_files","input":{"prompt_name":"Need_to_Requirement_Impact_rend","file_reference_names":["EBSD_Requirements.csv","EBSD_Needs.csv"]}}]}', 'model': 'qwen-3.6-27b', 'role': 'assistant'})]
# input data: {'filename': 'replay.ipynb'}
# resolved input: {'filename': 'replay.ipynb'}
# JIT Input: {'filename': 'replay.ipynb'}

# %%
result = agent.run(
    "notebook_export",
    input_data={
        "export_html": True,
        "source_ipynb": r"/home/simcenter/studio/knowledge_partner/EBSD_Requirements_Analysis.ipynb",
    },
    agent=agent
)
# Out:
# input data: {'export_html': True, 'source_ipynb': '/home/simcenter/studio/knowledge_partner/EBSD_Requirements_Analysis.ipynb'}
# resolved input: {'export_html': True, 'source_ipynb': '/home/simcenter/studio/knowledge_partner/EBSD_Requirements_Analysis.ipynb'}
# JIT Input: {'export_html': True, 'source_ipynb': '/home/simcenter/studio/knowledge_partner/EBSD_Requirements_Analysis.ipynb'}
